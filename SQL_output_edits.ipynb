# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import pandas as pd
from sqlalchemy import create_engine
# import geopandas as gpd
import seaborn as sns
import matplotlib as plt

# %%
conn_string = 'mysql://{user}:{password}@{host}/{db}?charset=utf8'.format(
    user='root', 
    password='x3rGjkz93e6CIkd7', 
    host = '35.237.252.223',  
    db='kayak'
)
engine = create_engine(conn_string)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-0df60e6adde1> in <module>()
#       5     db='kayak'
#       6 )
# ----> 7 engine = create_engine(conn_string)
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     417     strategy = kwargs.pop('strategy', default_strategy)
#     418     strategy = strategies.strategies[strategy]
# --> 419     return strategy.create(*args, **kwargs)
#     420
#     421
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      78                 if k in kwargs:
#      79                     dbapi_args[k] = pop_kwarg(k)
# ---> 80             dbapi = dialect_cls.dbapi(**dbapi_args)
#      81
#      82         dialect_args['dbapi'] = dbapi
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in dbapi(cls)
#     100     @classmethod
#     101     def dbapi(cls):
# --> 102         return __import__('MySQLdb')
#     103
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
#
# ModuleNotFoundError: No module named 'MySQLdb'

# %%
total = '''
SELECT *
FROM kayak.flight
WHERE Airline = 'Delta'
    AND Destination = 'LAS'
'''
df = pd.read_sql(total, con=engine)
df
# Out:
#     Airline  Price        Date      Time           Timestamp Destination  \
# 0     Delta    367  2018-12-23   8:15 am 2018-11-29 20:02:11         LAS
# 1     Delta    601  2018-12-23   6:13 pm 2018-11-29 20:02:11         LAS
# 2     Delta    296  2018-12-24   7:55 pm 2018-11-29 20:02:24         LAS
# 3     Delta    318  2018-12-24   7:30 am 2018-11-29 20:02:24         LAS
# 4     Delta    350  2018-12-24   8:07 am 2018-11-29 20:02:24         LAS
# 5     Delta    378  2018-12-25   7:00 am 2018-11-29 20:02:35         LAS
# 6     Delta    459  2018-12-25  11:40 am 2018-11-29 20:02:35         LAS
# 7     Delta    465  2018-12-25   9:30 am 2018-11-29 20:02:35         LAS
# 8     Delta   1236  2018-12-28  10:00 am 2018-11-29 20:03:52         LAS
# 9     Delta    238  2018-12-29   8:35 pm 2018-11-29 20:04:27         LAS
# 10    Delta    317  2018-12-29   5:54 pm 2018-11-29 20:04:27         LAS
# 11    Delta    354  2018-12-29  10:33 am 2018-11-29 20:04:27         LAS
# 12    Delta    277  2018-12-30   5:35 pm 2018-11-29 20:04:44         LAS
# 13    Delta    374  2018-12-22   8:35 pm 2018-11-29 21:48:20         LAS
# 14    Delta    297  2018-12-23   8:35 pm 2018-11-29 21:48:29         LAS
# 15    Delta    327  2018-12-23   2:59 pm 2018-11-29 21:48:29         LAS
# 16    Delta    327  2018-12-23   1:55 pm 2018-11-29 21:48:29         LAS
# 17    Delta    340  2018-12-24   8:35 am 2018-11-29 21:48:48         LAS
# 18    Delta    344  2018-12-24   8:20 pm 2018-11-29 21:48:48         LAS
# 287   Delta    169  2018-12-30   8:35 pm 2018-12-03 16:02:04         LAS
# 288   Delta    194  2018-12-30   3:30 pm 2018-12-03 16:02:04         LAS
# 289   Delta    238  2018-12-30   8:30 am 2018-12-03 16:02:04         LAS
# 290   Delta    297  2019-01-01   7:55 pm 2018-12-03 16:02:29         LAS
#
#                                             Prediction
# 0            We're still gathering data for this route
# 1            We're still gathering data for this route
# 2    Prices predicted to rise <br> <span class='pri...
# 3    Prices predicted to rise <br> <span class='pri...
# 4    Prices predicted to rise <br> <span class='pri...
# 5        Prices are unlikely to decrease within 7 days
# 6        Prices are unlikely to decrease within 7 days
# 7        Prices are unlikely to decrease within 7 days
# 8        Prices are unlikely to decrease within 7 days
# 9            We're still gathering data for this route
# 10           We're still gathering data for this route
# 11           We're still gathering data for this route
# 12       Prices are unlikely to decrease within 7 days
# 13       Prices are unlikely to decrease within 7 days
# 14       Prices are unlikely to decrease within 7 days
# 15       Prices are unlikely to decrease within 7 days
# 16       Prices are unlikely to decrease within 7 days
# 17       Prices are unlikely to decrease within 7 days
# 18       Prices are unlikely to decrease within 7 days
# 19       Prices are unlikely to decrease within 7 days
# 20       Prices are unlikely to decrease within 7 days
# 21       Prices are unlikely to decrease within 7 days
# 22           We're still gathering data for this route
# 23       Prices are unlikely to decrease within 7 days
# 24       Prices are unlikely to decrease within 7 days
# 25       Prices are unlikely to decrease within 7 days
# 26       Prices are unlikely to decrease within 7 days
# 27       Prices are unlikely to decrease within 7 days
# 28       Prices are unlikely to decrease within 7 days
# 29       Prices are unlikely to decrease within 7 days
# ..                                                 ...
# 261      Prices are unlikely to decrease within 7 days
# 262      Prices are unlikely to decrease within 7 days
# 263      Prices are unlikely to decrease within 7 days
# 264      Prices are unlikely to decrease within 7 days
# 265      Prices are unlikely to decrease within 7 days
# 266      Prices are unlikely to decrease within 7 days
# 267      Prices are unlikely to decrease within 7 days
# 268  Prices predicted to rise <br> <span class='pri...
# 269      Prices are unlikely to decrease within 7 days
# 270      Prices are unlikely to decrease within 7 days
# 271  Prices predicted to rise <br> <span class='pri...
# 272      Prices are unlikely to decrease within 7 days
# 273      Prices are unlikely to decrease within 7 days
# 274      Prices are unlikely to decrease within 7 days
# 275  Prices predicted to rise <br> <span class='pri...
# 276  Prices predicted to rise <br> <span class='pri...
# 277      Prices are unlikely to decrease within 7 days
# 278      Prices are unlikely to decrease within 7 days
# 279  Prices predicted to rise <br> <span class='pri...
# 280  Prices predicted to rise <br> <span class='pri...
# 281      Prices are unlikely to decrease within 7 days
# 282      Prices are unlikely to decrease within 7 days
# 283      Prices are unlikely to decrease within 7 days
# 284          We're still gathering data for this route
# 285  Prices predicted to rise <br> <span class='pri...
# 286      Prices are unlikely to decrease within 7 days
# 287      Prices are unlikely to decrease within 7 days
# 288      Prices are unlikely to decrease within 7 days
# 289      Prices are unlikely to decrease within 7 days
# 290      Prices are unlikely to decrease within 7 days
#
# [291 rows x 7 columns]
