# %%
import requests
from bs4 import BeautifulSoup
from lxml import html
import json
import pandas
import re

# %%
url = 'https://www.kayak.com'
r = requests.get(url)
layer1Cookies = r.cookies

url2 = url + '/s/horizon/flights/results/FlightSearchPoll'

origin_code = 'WAS'
origin_location = 'WASHINGTON'
destination_code = 'AMD'
destination_location = 'Ahmedabad'
depart_date = '2018-12-20'
return_date = '2019-01-27'

referer = 'https://www.kayak.com/flights/'+origin_code+'-'+destination_code+'/'+depart_date+'/'+return_date
headers = {
    'Host': 'www.kayak.com',
    'User-Agent': 'Chrome/63 (Macintosh; Intel Mac OS X 10.11; rv:57.0) Gecko/20100101 Firefox/57.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': referer,
    'Content-Type': 'application/x-www-form-urlencoded',
    'X-CSRF': 'kAqI1NgGh$DJnEUpiSDOWpdQXzlgAwG8EVOCd$gXO08-hpumC4oNpaOjz15GO_q9a5FdZPonpC2kF4CBYjEPh14',
    'X-RequestId': 'flights#frontdoor#Ag$s9g',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Length': '1094'
}

url3 = 'flights/'+origin_code+'-'+destination_code+'/'+depart_date+'/'+return_date

params1 = {
    'searchId':'',
    'poll':'true',
    'pollNumber':'0',
    'applyFilters':'true',
    'filterState':'',
    'useViewStateFilterState':'false',
    'pageNumber':'1',
    'append':'false',
    'pollingId':'593601',  #interesting. explore further
    'requestReason':'POLL',
    'isSecondPhase':'false',
    'textAndPageLocations':'bottom,right',
    'displayAdPageLocations':'none',
    'existingAds':'false',
    'activeLeg':'-1',
    'view':'list',
    'renderPlusMinusThreeFlex':'false',
    'renderAirlineStopsMatrix':'false',
    'renderFlexHeader':'true',
    'tab':'flights',
    'pageOrigin':'F..FD..M0',
    'src':'',
    'searchingAgain':'',
    'c2s':'',
    'po':'',
    'personality':'',
    'provider':'',
    'isMulticity':'false',
    'flex_category':'exact',
    'depart_date':depart_date,
    'return_date':return_date,
    'oneway':'false',
    'origincode':origin_code,  #change accordingly
    'origin':origin_code, #change accordingly
    'origin_location':origin_location, #change accordingly
    'origin_code':'', #change accordingly
    'nearby_origin':'false',
    'destination':destination_code, #change accordingly
    'destination_location':destination_location, #change accordingly
    'destination_code':'', #change accordingly
    'nearby_destination':'false',
    'countrySearch':'false',
    'depart_date_canon':depart_date, #change accordingly
    'return_date_canon':return_date, #change accordingly
    'travelers':'1',
    'adults':'1',
    'seniors':'0',
    'youth':'0',
    'child':'0',
    'seatInfant':'0',
    'lapInfant':'0',
    'cabin':'e',
    'cabinDisplayType':'Economy',
    'vertical':'flights',
    'url':url3,
    'id':'',
    'navigateToResults':'false',
    'ajaxts':'',
    'scriptsMetadata':'',
    'stylesMetadata':'',
}


result = requests.post(url2, headers = headers, data = params1, cookies = layer1Cookies)
text = result.json()

text = BeautifulSoup(text['content'], 'html.parser')

# %%
text
# Out:
# <div data-ajax-replace="" id="watchedItemContainer">
# </div>
# <div class="aboveHeaderContainer " data-ajax-replace="" id="aboveHeaderContainer">
# <div class="Flights-Results-FlightAboveHeaderContent FlightAboveHeaderContent" id="GX8D">
# <div aria-expanded="false" class="flexMatrixWrapper">
# </div>
# <div aria-expanded="false" class="airlineWrapper">
# </div>
# </div>
# </div>
# <div class="aboveResultsContainer" data-ajax-replace="" id="aboveResultsContainer">
# <div class="Flights-Results-FlightAboveResultsContent" id="aK50">
# </div>
# </div>
# <div id="customTicketHeader">
# </div>
# <div data-ajax-replace="" id="flexHeader">
# <div class="Flights-Results-Filters-FlexDateHeader " id="WBEv">
# <div class="keel-grid flex-grid" id="WBEv-flex-grid">
# <div class="col-1-5 flex-option" data-depart="true" data-difference="-1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="WwPK">
# <div>
# <div class="itemTitle">
# <div class="js-title">Depart</div>
# <div class="dow js-subtitle">Dec 19</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="true" data-difference="1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="c7NiG">
# <div>
# <div class="itemTitle">
# <div class="js-title">Depart</div>
# <div class="dow js-subtitle">Dec 21</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="true" data-difference="0">
# <div class="Flights-Results-Filters-FlexDateItem exact empty border" id="c7OJG">
# <div>
# <div class="itemTitle">
# <div class="js-title">Exact Dates</div>
# <div class="dow js-subtitle">Dec 20 - Jan 27</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="false" data-difference="-1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="a_gE">
# <div>
# <div class="itemTitle">
# <div class="js-title">Return</div>
# <div class="dow js-subtitle">Jan 26</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="false" data-difference="1">
# <div class="Flights-Results-Filters-FlexDateItem empty" id="ctEX">
# <div>
# <div class="itemTitle">
# <div class="js-title">Return</div>
# <div class="dow js-subtitle">Jan 28</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Base-Results-ResultsList Flights-Results-FlightResultsList" id="searchResultsList">
# <div id="DaEiOHjMFi-1">
# <div aria-label="Advertisement from emirates.com/us: Fly Emirates to Ahmedabad Take advantage of our complimentary generous baggage allowance of 2 pieces when you fly." class="Common-Kn-Rp-Inline flights phoenix-rising clearfix type-provider rp-contrast" id="inline-1" onclick="R9.events.publish('ecommerce.track', {event: 'inline.ad'});" role="link" tabbable="" tabindex="0">
# <nav class="aria-controls">
# <a href="javascript:void(0)" id="inline-1-skip">Skip this item</a>
# </nav>
# <img alt="" class="inlineAdTracking" src="/k/redirect/tracking?url=&amp;h=MqeKX7mm44UdD6ZUK88_4n88u2Y&amp;plid=9930852&amp;searchID=DaEiOHjMFi"/>
# <div class="Common-Kn-Rp-FlightInline simple no-price " id="xke5" onclick="window.open('https://www.kayak.com/s/clickthrough.jsp?ctyp=InlineOpaqueAdBooking&amp;ptyp=F&amp;orig=F..RP..M1&amp;octid=&amp;plid=9930852&amp;cpnid=7040978&amp;pid=EmiratesGlobalUS_FIOAD_US&amp;prv=EmiratesGlobalUS_FIOAD_US&amp;srch=DaEiOHjMFi&amp;ploc=US&amp;displayRail=Rslt&amp;rank=1&amp;atype=inline&amp;prc=&amp;xpExt=&amp;aidExt=&amp;lid=EmiratesGlobalUS_FIOAD_US-DaEiOHjMFi&amp;qorig=Airport:WAS&amp;qdest=Airport:AMD&amp;qstart=1545282000000&amp;qend=1548565200000&amp;qtravelers=1&amp;qrooms=0&amp;qow=false&amp;qfcc=e&amp;qdctid=29732&amp;qdac=AMD&amp;qshour=-1&amp;qehour=-1&amp;resid=&amp;bookid=&amp;seekProv=&amp;qadults=1&amp;qchild=0&amp;qns=false&amp;qnearby=0&amp;qnearbyo=false&amp;qnearbyd=false&amp;qcages=&amp;qinfantseat=0&amp;qinfantlap=0&amp;qsenior=0&amp;pgNum=1©Id=100001339&amp;iar=1&amp;stid=23945014&amp;ah=1ktZ5cXABQ1KPjxJ4vWh5AEe_9GdkUKTc_zeFyOZy84&amp;pj=A9L5911iv57To3NDr9d4xw==')">
# <div class="content-col ">
# <div class="icon">
# <img alt="emirates.com/us" src="/kimg/logos/457387a7d143a997.png"/>
# </div>
# <div class="content">
# <div class="inlineAdHeadline">Fly Emirates to Ahmedabad</div>
# <div class="inlineAdDescription no-options">
# <span>Take advantage of our complimentary generous baggage allowance of 2 pieces when you fly.</span>
# </div>
# <div class="inlineAdFooter clean">
# <span>emirates.com/us | </span> <span class="sponsoredTag">Sponsored</span>
# </div>
# </div>
# </div>
# <div class="price-col inlineAdPriceColumn no-price right-alignment">
# <div class="inlineAdSelect">
# <div class="bookitselect">
# <a aria-label="Ad: View deal from emirates.com/us" class="ui-button Button-Gradient" href="javascript:void(0)" onclick="" rel="nofollow" target="">
# <div class="view-deal">
# View Deal </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div aria-describedby="wXKw-describedby" aria-label="Result number 2: Info from Etihad Airways." class="Base-Results-HorizonResult Flights-Results-FlightResultItem phoenix-rising sleek rp-contrast " data-resultid="b00bd99c12753a00e82a11f0ad46ca0e" id="wXKw" page-idx="1" tabbable="" tabindex="0">
# <nav class="aria-controls">
# <p id="wXKw-describedby" style="display: none"> Leg 1: Provided by Etihad Airways. Departs from Washington, DC - Dulles Intl on 12/20 at 9:25 pm, lands in Ahmedabad, India - Ahmedabad on 12/22 at 3:20 am. 1 stop (AUH). Total duration: 19h 25m. Leg 2: Provided by Etihad Airways. Departs from Ahmedabad, India - Ahmedabad on 1/27 at 4:35 am, lands in Washington, DC - Dulles Intl on 1/27 at 4:55 pm. 1 stop (AUH). Total duration: 22h 50m.</p>
# <a href="javascript:void(0)" id="wXKw-skip">Go to next result</a>
# <a href="#wXKw-price">Go to price</a>
# <a href="#wXKw-info">Go to flight info</a>
# <div aria-labelledby="wXKw-aria-details-open" class="Flights-Results-DetailsLink " id="wXKw-aria-details">
# <a aria-pressed="false" class="detailsToggle" href="javascript:void(0)" id="wXKw-aria-details-toggleMore" role="button">
# <span class="openText" id="wXKw-aria-details-open">See details</span>
# <span class="closeText" id="wXKw-aria-details-close">Hide details</span>
# </a>
# </div>
# </nav>
# <div class="resultWrapper">
# <div class="resultInner">
# <div class="inner-grid keel-grid">
# <div class="col-info result-column">
# <div class="mainInfo" id="wXKw-mainInfo">
# <div class="Flights-Results-ResultInfo multiple-legs" id="wXKw-info">
# <ol class="flights">
# <li class="flight with-gutter">
# <div class="Flights-Results-LegInfo Flights-Results-LegInfoSleek no-carry-on-column" id="wXKw-info-leg-0">
# <div class="container">
# <div class="section select-leg" id="wXKw-info-leg-0-select-leg-column">
# <div class="select-leg-checkbox" id="wXKw-info-leg-0-select-leg-wrapper">
# <div class="StyleJamCheckbox _bd">
# <input aria-checked="false" aria-disabled="false" aria-label="Show results with this flight only" class="_b _iB _Ir _dc" data-switch-info='{"presentation":"MUTED"}' id="wXKw-info-leg-0-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="_bd _L _M _m _N _kM _R5 _bg _ej _e _bj _br3 _bm _bp _br0 _7D _dT _br1 _ds _br2 _bv _bU _ga _PM _bgV _bsh _bsi _x2" id="wXKw-info-leg-0-select-leg-checkbox-icon"></div>
# <label class="_bd _a _Sw _Sx _e _b1 _Sv _z4 _bsj _br4" data-name="specleg" for="wXKw-info-leg-0-select-leg-checkbox" id="wXKw-info-leg-0-select-leg-checkbox-label"></label>
# </div>
# </div>
# </div>
# <div class="section carrier">
# <img alt="Etihad Airways logo" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="section times">
# <div class="top">
# <span class="time-pair"> <span class="depart-time base-time">9:25 </span>
# <span class="time-meridiem meridiem">pm</span>
# </span>
# <span class="sep">—</span>
# <span class="time-pair">
# <span class="arrival-time base-time">3:20 </span>
# <span class="time-meridiem meridiem">am</span>
# <span class="adendum" title="Flight lands 2 days later">+2</span>
# </span>
# </div>
# <div class="bottom">Etihad Airways</div> </div>
# <div class="section stops">
# <div class="top">
# 1 stop </div>
# <div class="bottom">
# <span class="js-layover" title="3h 45m layover, &lt;b&gt;Abu Dhabi Intl&lt;/b&gt;">AUH</span> </div>
# </div>
# <div class="section duration">
# <div class="top">19h 25m</div>
# <div class="bottom">
# <span>IAD</span>
# <span class="sep">&amp;dash;</span>
# <span>AMD</span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="flight ">
# <div class="Flights-Results-LegInfo Flights-Results-LegInfoSleek no-carry-on-column" id="wXKw-info-leg-1">
# <div class="container">
# <div class="section select-leg" id="wXKw-info-leg-1-select-leg-column">
# <div class="select-leg-checkbox" id="wXKw-info-leg-1-select-leg-wrapper">
# <div class="StyleJamCheckbox _bd">
# <input aria-checked="false" aria-disabled="false" aria-label="Show results with this flight only" class="_b _iB _Ir _dc" data-switch-info='{"presentation":"MUTED"}' id="wXKw-info-leg-1-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="_bd _L _M _m _N _kM _R5 _bg _ej _e _bj _br3 _bm _bp _br0 _7D _dT _br1 _ds _br2 _bv _bU _ga _PM _bgV _bsh _bsi _x2" id="wXKw-info-leg-1-select-leg-checkbox-icon"></div>
# <label class="_bd _a _Sw _Sx _e _b1 _Sv _z4 _bsj _br4" data-name="specleg" for="wXKw-info-leg-1-select-leg-checkbox" id="wXKw-info-leg-1-select-leg-checkbox-label"></label>
# </div>
# </div>
# </div>
# <div class="section carrier">
# <img alt="Etihad Airways logo" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="section times">
# <div class="top">
# <span class="time-pair"> <span class="depart-time base-time">4:35 </span>
# <span class="time-meridiem meridiem">am</span>
# </span>
# <span class="sep">—</span>
# <span class="time-pair">
# <span class="arrival-time base-time">4:55 </span>
# <span class="time-meridiem meridiem">pm</span>
# </span>
# </div>
# <div class="bottom">Etihad Airways</div> </div>
# <div class="section stops">
# <div class="top">
# 1 stop </div>
# <div class="bottom">
# <span class="js-layover" title="4h 30m layover, &lt;b&gt;Abu Dhabi Intl&lt;/b&gt;">AUH</span> </div>
# </div>
# <div class="section duration">
# <div class="top">22h 50m</div>
# <div class="bottom">
# <span>AMD</span>
# <span class="sep">&amp;dash;</span>
# <span>IAD</span>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ol>
# </div>
# </div>
# </div>
# <div class="col-price result-column" id="wXKw-priceSection">
# <div class="Flights-Results-FlightPriceSection right-alignment sleek" id="wXKw-price">
# <div class="top-row">
# <div class="left-column">
# <div class="Flights-Results-FlightFeeIcons _v" id="wXKw-price-flight-fee-icons">
# <div class="_0T _A _0V _N3 _0X _0Z _bZW _bZX _dT _bZY _bZZ _bU _bZ0 _bZ1 _kM _Km _FP _ds _fx _fw _s _Av _ga _x _kh _bZ3" id="wXKw-price-flight-fee-icons-carryOnBags">
# <div class="_k _O _QB _bfv">
# <svg class="" fill="currentColor" height="10" viewbox="0 0 9 10" width="9" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-carry-on-bag"></use></svg> </div>
# <div class="_k _o _QB _bcW">
# 1
# </div>
# </div>
# <div class="_0T _A _0V _N3 _0X _0Z _bZW _bZX _dT _bZY _bZZ _bU _bZ0 _bZ1 _kM _Km _FP _ds _fx _fw _s _Av _ga _x _kh _bZ3" id="wXKw-price-flight-fee-icons-checkedBags">
# <div class="_k _O _QB _mi">
# <svg class="_z" fill="currentColor" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-checked-bag_z"></use></svg> </div>
# <div class="_k _o _QB _bcW">
# 2
# </div>
# </div>
# </div>
# </div>
# <div class="Common-Results-ResultOptionsMenu Theme-grey _uN _eQ _g2 _bg5" id="v_qW">
# <button aria-label="More options" class="_a _A _r _s _v _z _wD Button-No-Standard-Style" id="v_qW-menu-trigger" title="More options">
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# </button>
# <div class="Common-Widgets-Tip-ToolTip" id="v_qW-menu-trigger-rendered-content">
# <div class="_A _q _v _fR _Gr _r0 _c1 _c2 _n">
# <div class="_r _gL _v _g2">
# <div class="Common-Trips-ResultItemSaveToTrips row-item grey" id="v_qW-save">
# <a aria-label="Watch flight" aria-pressed="false" class="layer-content watchlist-style" href="javascript:void(0)" id="v_qW-save-save" role="button">
# <div class="icon icon-filled">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 0H5C3.896 0 3 .895 3 2v22l9-8 9 8V2c0-1.105-.896-2-2-2zm-7.757 12L7 7.757l1.414-1.414 2.828 2.828 4.95-4.95 1.414 1.415L11.243 12z"></path></svg> </div>
# <div class="icon icon-outline">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 2v17.546l-7-6.222-7 6.222V2h14m0-2H5C3.896 0 3 .895 3 2v22l9-8 9 8V2c0-1.105-.896-2-2-2z"></path></svg> </div>
# <span class="title saveLinkText" id="v_qW-save-title">
# Watch flight
# </span>
# </a>
# </div>
# </div>
# <div class="_r _gL _v _g2 _bp _bo _dT">
# <a aria-haspopup="true" aria-label="Share" class="Common-Results-ShareLink Icon-default row-item grey" href="javascript:void(0)" id="v_qW-share" role="button">
# <div class="shareIcon" id="v_qW-share-icon">
# <svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g transform="translate(.49 .49)"><ellipse cx="13.935" cy="3.036" rx="3.065" ry="3.036"></ellipse><ellipse cx="3.065" cy="9.107" rx="3.065" ry="3.036"></ellipse><ellipse cx="13.935" cy="13.964" rx="3.065" ry="3.036"></ellipse><path d="M4.94 6.987l6.567-3.492.749 1.408-6.568 3.492zM5.312 10.97l6.568 3.492.748-1.408L6.06 9.562z"></path></g></svg> </div>
# <div class="shareLabel" id="v_qW-share-label">
# Share
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="booking" id="wXKw-price-bookingSection">
# <div class="multibook-dropdown">
# <div class="Common-Booking-VerticalMultiBookDropdown Flights-Booking-FlightVerticalMultiBookDropdown align-right" id="wXKw-price-mb">
# <div class="above-button" id="wXKw-price-mb-above-button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider multi-row Theme-featured-large featured-provider " id="wXKw-price-mb-aE-1370e69c110">
# <a aria-label="Info from Etihad Airways" class="booking-link" href="/book/flight?code=DaEiOHjMFi.L_66gr_0DL6X1jsfYjAW7A.-100.b00bd99c12753a00e82a11f0ad46ca0e&amp;h=59e2ee9a6f24&amp;sub=E-1370e69c110" id="wXKw-price-mb-aE-1370e69c110-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# Info </span>
# <span class="providerName option-text">
# Etihad Airways
# </span>
# </a>
# </div>
# </div>
# <div class="above-button">
# </div>
# <div class="keel-grid multibookGrid" id="wXKw-price-mb-dropdown-grid" role="listbox">
# <div class="col col-best ">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-m bookingButton " id="wXKw-price-mb-best" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small featured-provider " id="wXKw-price-mb-bE-1370e69c110">
# <a aria-label="View Deal" class="booking-link" href="/book/flight?code=DaEiOHjMFi.L_66gr_0DL6X1jsfYjAW7A.-100.b00bd99c12753a00e82a11f0ad46ca0e&amp;h=59e2ee9a6f24&amp;sub=E-1370e69c110" id="wXKw-price-mb-bE-1370e69c110-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# View Deal
# </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="fare-family">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="detailsWrapper" id="wXKw-detailsWrapper">
# <div class="detailsContent detailsContainer" id="wXKw-detailsContent">
# <div class="Flights-Results-FlightResultDetails Flights-Results-FlightResultDetailsV3 tab-refresh" id="wXKw-details">
# <section aria-expanded="true" class="details-section overviewSection" data-tab="overview" id="wXKw-details-leg-details" role="tabpanel">
# <div class="section-content">
# <div class="Flights-Results-FlightLegDetails" id="M706">
# <div class="header">
# <div class="spec-leg left">
# <span class="leg-filter-checkbox">
# <span class="checkbox-wrapper" id="M706-select-leg-wrapper">
# <div class="Common-Widgets-Checkbox-Checkbox select-leg-checkbox disable-mouseout-animation size-m ">
# <input aria-checked="false" aria-disabled="false" aria-labelledby="M706-select-leg-checkbox-label" id="M706-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="icon" id="M706-select-leg-checkbox-icon"></div>
# <label class="label" data-name="specleg" for="M706-select-leg-checkbox" id="M706-select-leg-checkbox-label">Depart</label>
# </div>
# </span>
# </span>
# </div>
# <div class="airports left">
# <span class="origin-destination">
# IAD - AMD
# </span>
# </div>
# <div class="times right">
# <span class="duration">19h 25m</span>
# </div>
# </div>
# <div class="content-card">
# <div class="segment-row" data-flightnumber="130">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Thu, Dec 20
# </div>
# <div class="arrival-date-warning">
# Lands Fri, Dec 21 </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Etihad Airways" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">9:25 pm</span>
# —
# <span class="time">7:10 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Washington</span>
# </span>
# -
# <span class="destination">
# <span class="city">Abu Dhabi</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 12h 45m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="o8RD">
# <div class="keel-grid iconGrid" id="o8RD-icons">
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Etihad Airways 130 · Wide-body jet · Boeing 787-9 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="Mp1c" tabindex="0">
# <div class="keel-grid layoverGrid warn">
# <div class="col-10-12">
# <div class="layoverText " id="Mp1c-layover-text">
# Change planes in Abu Dhabi (AUH)
# </div>
# <div class="layoverWarning ">
# Long layover </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">3h 45m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="288">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Fri, Dec 21
# </div>
# <div class="arrival-date-warning">
# Lands Sat, Dec 22 </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid last" tabindex="0">
# <div class="icon-column">
# <img alt="Etihad Airways" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">10:55 pm</span>
# —
# <span class="time">3:20 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Abu Dhabi</span>
# </span>
# -
# <span class="destination">
# <span class="city">Ahmedabad</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 2h 55m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="ne6h">
# <div class="keel-grid iconGrid" id="ne6h-icons">
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Etihad Airways 288 · Narrow-Body Jet · Airbus A321-100/200 </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-content">
# <div class="Flights-Results-FlightLegDetails" id="c1sY5">
# <div class="header">
# <div class="spec-leg left">
# <span class="leg-filter-checkbox">
# <span class="checkbox-wrapper" id="c1sY5-select-leg-wrapper">
# <div class="Common-Widgets-Checkbox-Checkbox select-leg-checkbox disable-mouseout-animation size-m ">
# <input aria-checked="false" aria-disabled="false" aria-labelledby="c1sY5-select-leg-checkbox-label" id="c1sY5-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="icon" id="c1sY5-select-leg-checkbox-icon"></div>
# <label class="label" data-name="specleg" for="c1sY5-select-leg-checkbox" id="c1sY5-select-leg-checkbox-label">Return</label>
# </div>
# </span>
# </span>
# </div>
# <div class="airports left">
# <span class="origin-destination">
# AMD - IAD
# </span>
# </div>
# <div class="times right">
# <span class="duration">22h 50m</span>
# </div>
# </div>
# <div class="content-card">
# <div class="segment-row" data-flightnumber="289">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Sun, Jan 27
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Etihad Airways" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">4:35 am</span>
# —
# <span class="time">6:30 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Ahmedabad</span>
# </span>
# -
# <span class="destination">
# <span class="city">Abu Dhabi</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 3h 25m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="c1S29">
# <div class="keel-grid iconGrid" id="c1S29-icons">
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Etihad Airways 289 · Wide-body jet · Airbus A330-200 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="c_pVI" tabindex="0">
# <div class="keel-grid layoverGrid warn">
# <div class="col-10-12">
# <div class="layoverText " id="c_pVI-layover-text">
# Change planes in Abu Dhabi (AUH)
# </div>
# <div class="layoverWarning ">
# Long layover </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">4h 31m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="131">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Sun, Jan 27
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid last" tabindex="0">
# <div class="icon-column">
# <img alt="Etihad Airways" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">11:00 am</span>
# —
# <span class="time">4:55 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Abu Dhabi</span>
# </span>
# -
# <span class="destination">
# <span class="city">Washington</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 14h 55m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="fHLQ">
# <div class="keel-grid iconGrid" id="fHLQ-icons">
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Etihad Airways 131 · Wide-body jet · Boeing 787-9 </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section aria-expanded="true" class="details-section bookingSection" data-tab="rates" id="wXKw-details-rates" role="tabpanel">
# <div class="Flights-Results-FlightRatesTable Flights-Results-FlightRatesTableV3 carry-on-design" id="fcJ8">
# <header class="main-header">
# <h3 class="title left">
# Booking Options </h3>
# </header>
# <section aria-readonly="true" class="table-section content-card" role="treegrid">
# <header class="rates-table-header">
# <div class="Flights-Results-FlightRatesTableHeader Flights-Results-FlightRatesTableHeaderV2 " id="q7rU" role="row">
# <div class="cell header-cell logo end-left-alignment" role="rowheader">
# <div class="header-cell-heading">
# Booking Site </div>
# </div>
# <div class="cell header-cell cabin" role="rowheader">
# <div class="header-cell-icon">
# <span class="cabin-icon">
# <svg fill="currentColor" height="19" viewbox="-0.5 0 15 19" width="15" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-seat-class"></use></svg> </span>
# </div>
# <div class="header-cell-heading">
# Class </div>
# </div>
# <div class="cell header-cell baggage-fees" role="rowheader">
# <div class="header-cell-icon">
# <svg class="" fill="currentColor" height="10" viewbox="0 0 9 10" width="9" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-carry-on-bag"></use></svg> </div>
# <div class="header-cell-heading">
# Carry-On Bag </div>
# </div>
# <div class="cell header-cell baggage-fees" role="rowheader">
# <div class="header-cell-icon">
# <svg fill="currentColor" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-checked-bag"></use></svg> </div>
# <div class="header-cell-heading">
# Checked Bag </div>
# </div>
# <div class="cell header-cell booking-total" role="rowheader">
# <div class="header-cell-icon">
# <svg height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-price-tag-filled"></use></svg> </div>
# <div class="header-cell-heading">
# You Pay </div>
# </div>
# </div>
# </header>
# <div class="provider-tables">
# <div aria-expanded="true" class="ratesTable table-panel" id="fcJ8-e" role="tabpanel">
# <ul class="provider-list ratesTable-e" data-category="e" role="rowgroup">
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-0" id="VMRe" role="row">
# <div class="cell logo end-left-alignment" role="gridcell">
# <img alt="Etihad Airways" class="site" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/h/EY.png?crop=false&amp;width=88&amp;height=31&amp;fallback=default3.png&amp;_v=e8ea77e60ab3ff8191cc52ec14180c7f83d5ee65" title="Etihad Airways"/>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="c28LI" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="c1LU2" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="VMRe-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small featured-provider " id="FAS7">
# <a aria-label="Info from Etihad Airways" class="booking-link" href="/book/flight?code=DaEiOHjMFi.L_66gr_0DL6X1jsfYjAW7A.-100.b00bd99c12753a00e82a11f0ad46ca0e&amp;h=59e2ee9a6f24&amp;sub=E-1370e69c110" id="FAS7-booking-link" role="button" tabindex="0" target="_blank">
# <span class="price option-text">
# Info </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </section>
# </div>
# </section>
# <div id="c4Y7E"></div>
# </div>
# </div>
# </div>
# <div id="PU6V"></div>
# </div>
# </div>
# </div>
# </div>
# <div id="FlightResultsDataLayer"></div>
# ;
