# %%
import requests
from bs4 import BeautifulSoup
from lxml import html
import json
import pandas
import re

# %%
url = 'https://www.kayak.com'
r = requests.get(url)
layer1Cookies = r.cookies

url2 = url + '/s/horizon/flights/results/FlightSearchPoll'

origin_code = 'WAS'
origin_location = 'WASHINGTON'
destination_code = 'AMD'
destination_location = 'Ahmedabad'
depart_date = '2018-12-20'
return_date = '2019-01-27'

referer = 'https://www.kayak.com/flights/'+origin_code+'-'+destination_code+'/'+depart_date+'/'+return_date
headers = {
    'Host': 'www.kayak.com',
    'User-Agent': 'Chrome/63 (Macintosh; Intel Mac OS X 10.11; rv:57.0) Gecko/20100101 Firefox/57.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': referer,
    'Content-Type': 'application/x-www-form-urlencoded',
    'X-CSRF': 'kAqI1NgGh$DJnEUpiSDOWpdQXzlgAwG8EVOCd$gXO08-hpumC4oNpaOjz15GO_q9a5FdZPonpC2kF4CBYjEPh14',
    'X-RequestId': 'flights#frontdoor#Ag$s9g',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Length': '1094'
}

url3 = 'flights/'+origin_code+'-'+destination_code+'/'+depart_date+'/'+return_date

params1 = {
    'searchId':'',
    'poll':'true',
    'pollNumber':'0',
    'applyFilters':'true',
    'filterState':'',
    'useViewStateFilterState':'false',
    'pageNumber':'1',
    'append':'false',
    'pollingId':'593601',  #interesting. explore further
    'requestReason':'POLL',
    'isSecondPhase':'false',
    'textAndPageLocations':'bottom,right',
    'displayAdPageLocations':'none',
    'existingAds':'false',
    'activeLeg':'-1',
    'view':'list',
    'renderPlusMinusThreeFlex':'false',
    'renderAirlineStopsMatrix':'false',
    'renderFlexHeader':'true',
    'tab':'flights',
    'pageOrigin':'F..FD..M0',
    'src':'',
    'searchingAgain':'',
    'c2s':'',
    'po':'',
    'personality':'',
    'provider':'',
    'isMulticity':'false',
    'flex_category':'exact',
    'depart_date':depart_date,
    'return_date':return_date,
    'oneway':'false',
    'origincode':origin_code,  #change accordingly
    'origin':origin_code, #change accordingly
    'origin_location':origin_location, #change accordingly
    'origin_code':'', #change accordingly
    'nearby_origin':'false',
    'destination':destination_code, #change accordingly
    'destination_location':destination_location, #change accordingly
    'destination_code':'', #change accordingly
    'nearby_destination':'false',
    'countrySearch':'false',
    'depart_date_canon':depart_date, #change accordingly
    'return_date_canon':return_date, #change accordingly
    'travelers':'1',
    'adults':'1',
    'seniors':'0',
    'youth':'0',
    'child':'0',
    'seatInfant':'0',
    'lapInfant':'0',
    'cabin':'e',
    'cabinDisplayType':'Economy',
    'vertical':'flights',
    'url':url3,
    'id':'',
    'navigateToResults':'false',
    'ajaxts':'',
    'scriptsMetadata':'',
    'stylesMetadata':'',
}


result = requests.post(url2, headers = headers, data = params1, cookies = layer1Cookies)
text = result.json()

text = BeautifulSoup(text['content'], 'html.parser')
# Out:
# <div data-ajax-replace="" id="watchedItemContainer">
# </div>
# <div class="aboveHeaderContainer " data-ajax-replace="" id="aboveHeaderContainer">
# <div class="Flights-Results-FlightAboveHeaderContent FlightAboveHeaderContent" id="LV70">
# <div aria-expanded="false" class="flexMatrixWrapper">
# </div>
# <div aria-expanded="false" class="airlineWrapper">
# </div>
# </div>
# </div>
# <div class="aboveResultsContainer" data-ajax-replace="" id="aboveResultsContainer">
# <div class="Flights-Results-FlightAboveResultsContent" id="TBDb">
# </div>
# </div>
# <div id="customTicketHeader">
# </div>
# <div data-ajax-replace="" id="flexHeader">
# <div class="Flights-Results-Filters-FlexDateHeader " id="kIzt">
# <div class="keel-grid flex-grid" id="kIzt-flex-grid">
# <div class="col-1-5 flex-option" data-depart="true" data-difference="-1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="c7f27">
# <div>
# <div class="itemTitle">
# <div class="js-title">Depart</div>
# <div class="dow js-subtitle">Dec 19</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="true" data-difference="1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="yOPI">
# <div>
# <div class="itemTitle">
# <div class="js-title">Depart</div>
# <div class="dow js-subtitle">Dec 21</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="true" data-difference="0">
# <div class="Flights-Results-Filters-FlexDateItem exact empty border" id="kupp">
# <div>
# <div class="itemTitle">
# <div class="js-title">Exact Dates</div>
# <div class="dow js-subtitle">Dec 20 - Jan 27</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="false" data-difference="-1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="Glna">
# <div>
# <div class="itemTitle">
# <div class="js-title">Return</div>
# <div class="dow js-subtitle">Jan 26</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="false" data-difference="1">
# <div class="Flights-Results-Filters-FlexDateItem empty" id="cUT7">
# <div>
# <div class="itemTitle">
# <div class="js-title">Return</div>
# <div class="dow js-subtitle">Jan 28</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Base-Results-ResultsList Flights-Results-FlightResultsList" id="searchResultsList">
# <div id="EdCCLH_bDe-1">
# <div aria-label="Advertisement from emirates.com/us: Fly Better to Ahmedabad with Emirates Enjoy free onboard Wi-Fi, gourmet cuisine and up to 3,500 channels of entertainment." class="Common-Kn-Rp-Inline flights phoenix-rising clearfix type-provider rp-contrast" id="inline-1" onclick="R9.events.publish('ecommerce.track', {event: 'inline.ad'});" role="link" tabbable="" tabindex="0">
# <nav class="aria-controls">
# <a href="javascript:void(0)" id="inline-1-skip">Skip this item</a>
# </nav>
# <img alt="" class="inlineAdTracking" src="/k/redirect/tracking?url=$&amp;h=Y69aQChpvxoE2gnKR9g4auOKkLg&amp;plid=9930852&amp;searchID=EdCCLH_bDe"/>
# <div class="Common-Kn-Rp-FlightInline simple no-price " id="OXOa" onclick="window.open('https://www.kayak.com/s/clickthrough.jsp?ctyp=InlineOpaqueAdBooking&amp;ptyp=F&amp;orig=F..RP..M1&amp;octid=&amp;plid=9930852&amp;cpnid=7040978&amp;pid=EmiratesGlobalUS_FIOAD_US&amp;prv=EmiratesGlobalUS_FIOAD_US&amp;srch=EdCCLH_bDe&amp;ploc=US&amp;displayRail=Rslt&amp;rank=1&amp;atype=inline&amp;prc=&amp;xpExt=&amp;aidExt=&amp;lid=EmiratesGlobalUS_FIOAD_US-EdCCLH_bDe&amp;qorig=Airport:WAS&amp;qdest=Airport:AMD&amp;qstart=1545282000000&amp;qend=1548565200000&amp;qtravelers=1&amp;qrooms=0&amp;qow=false&amp;qfcc=e&amp;qdctid=29732&amp;qdac=AMD&amp;qshour=-1&amp;qehour=-1&amp;resid=&amp;bookid=&amp;seekProv=&amp;qadults=1&amp;qchild=0&amp;qns=false&amp;qnearby=0&amp;qnearbyo=false&amp;qnearbyd=false&amp;qcages=&amp;qinfantseat=0&amp;qinfantlap=0&amp;qsenior=0&amp;pgNum=1©Id=0&amp;iar=1&amp;stid=23945014&amp;ah=JfCKddJJP_IZfnWAv3Uzqau8WSEwyyv4RvGxlr$VJng&amp;pj=A9L5911iv57To3NDr9d4xw==')">
# <div class="content-col ">
# <div class="icon">
# <img alt="emirates.com/us" src="/kimg/logos/457387a7d143a997.png"/>
# </div>
# <div class="content">
# <div class="inlineAdHeadline">Fly Better to Ahmedabad with Emirates</div>
# <div class="inlineAdDescription no-options">
# <span>Enjoy free onboard Wi-Fi, gourmet cuisine and up to 3,500 channels of entertainment.</span>
# </div>
# <div class="inlineAdFooter clean">
# <span>emirates.com/us | </span> <span class="sponsoredTag">Sponsored</span>
# </div>
# </div>
# </div>
# <div class="price-col inlineAdPriceColumn no-price right-alignment get-in-formation">
# <div class="inlineAdSelect">
# <div class="bookitselect">
# <a aria-label="Ad: View deal from emirates.com/us" class="ui-button Button-Gradient" href="javascript:void(0)" onclick="" rel="nofollow" target="">
# <div class="view-deal">
# View Deal </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Flights-Results-BestFlights phoenix-rising" id="UsL6">
# <div class="best-flights-list">
# <div class="best-flights-border-container"></div>
# <div class="best-flights-header">
# <span class="title">
# Best Flights
# </span>
# <span class="information" id="UsL6-tooltip-icon">
# ⓘ
# </span>
# </div>
# <div aria-describedby="c_qlM-describedby" aria-label="Best flight number 1: $1743 from Hacker Fare." class="Base-Results-HorizonResult Flights-Results-FlightResultItem phoenix-rising get-in-formation sleek rp-contrast " data-resultid="e6d5d57ed5bdaf4d98d83184bfd81bf3" id="c_qlM" page-idx="0" tabbable="" tabindex="0">
# <nav class="aria-controls">
# <p id="c_qlM-describedby" style="display: none"> Leg 1: Provided by Multiple Airlines. Departs from Washington, DC - Dulles Intl on 12/20 at 5:00 pm, lands in Ahmedabad, India - Ahmedabad on 12/22 at 4:35 am. 3 stops (RUH, KWI…). Total duration: 25h 05m. Leg 2: Provided by Etihad Airways. Departs from Ahmedabad, India - Ahmedabad on 1/27 at 8:30 pm, lands in Washington, DC - Dulles Intl on 1/28 at 4:55 pm. 1 stop (AUH). Total duration: 30h 55m. We think you'll like these flights based on their duration, price, number of stops and carrier type.</p>
# <a href="javascript:void(0)" id="c_qlM-skip">Go to next result</a>
# <a href="#c_qlM-price">Go to price</a>
# <a href="#c_qlM-info">Go to flight info</a>
# <div aria-labelledby="c_qlM-aria-details-open" class="Flights-Results-DetailsLink " id="c_qlM-aria-details">
# <a aria-pressed="false" class="detailsToggle" href="javascript:void(0)" id="c_qlM-aria-details-toggleMore" role="button">
# <span class="openText" id="c_qlM-aria-details-open">See details</span>
# <span class="closeText" id="c_qlM-aria-details-close">Hide details</span>
# </a>
# </div>
# </nav>
# <div class="resultWrapper">
# <div class="resultInner">
# <div class="inner-grid keel-grid">
# <div class="col-info result-column">
# <div class="mainInfo" id="c_qlM-mainInfo">
# <div class="Flights-Results-ResultInfo multiple-legs" id="c_qlM-info">
# <ol class="flights">
# <li class="flight with-gutter">
# <div class="Flights-Results-LegInfo Flights-Results-LegInfoSleek no-carry-on-column" id="c_qlM-info-leg-0">
# <div class="container">
# <div class="section select-leg" id="c_qlM-info-leg-0-select-leg-column">
# <div class="select-leg-checkbox" id="c_qlM-info-leg-0-select-leg-wrapper">
# <div class="StyleJamCheckbox _bd">
# <input aria-checked="false" aria-disabled="false" aria-label="Show results with this flight only" class="_b _iB _Ir _dc" data-switch-info='{"presentation":"MUTED"}' id="c_qlM-info-leg-0-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="_bd _L _M _m _N _kM _R5 _bg _ej _e _bj _br3 _bm _bp _br0 _7D _dT _br1 _ds _br2 _bv _bU _ga _PM _bgV _bsh _bsi _x2" id="c_qlM-info-leg-0-select-leg-checkbox-icon"></div>
# <label class="_bd _a _Sw _Sx _e _b1 _Sv _z4 _bsj _br4" data-name="specleg" for="c_qlM-info-leg-0-select-leg-checkbox" id="c_qlM-info-leg-0-select-leg-checkbox-label"></label>
# </div>
# </div>
# </div>
# <div class="section carrier">
# <svg height="25" viewbox="0 0 25 25" width="25" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-multiple-airlines"></use></svg> </div>
# <div class="section times">
# <div class="top">
# <span class="time-pair"> <span class="depart-time base-time">5:00 </span>
# <span class="time-meridiem meridiem">pm</span>
# </span>
# <span class="sep">—</span>
# <span class="time-pair">
# <span class="arrival-time base-time">4:35 </span>
# <span class="time-meridiem meridiem">am</span>
# <span class="adendum" title="Flight lands 2 days later">+2</span>
# </span>
# </div>
# <div class="bottom">Multiple Airlines</div> </div>
# <div class="section stops">
# <div class="top">
# 3 stops </div>
# <div class="bottom">
# <span class="js-layover" title="2h 50m layover, &lt;b&gt;Riyadh King Khaled Intl&lt;/b&gt;">RUH</span>, <span class="js-layover" title="2h 50m layover, &lt;b&gt;Kuwait City&lt;/b&gt;">KWI</span>, <span class="js-layover" title="2h layover, &lt;b&gt;Sharjah&lt;/b&gt;">...</span> </div>
# </div>
# <div class="section duration">
# <div class="top">25h 05m</div>
# <div class="bottom">
# <span>IAD</span>
# <span class="sep">&amp;dash;</span>
# <span>AMD</span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="flight ">
# <div class="Flights-Results-LegInfo Flights-Results-LegInfoSleek no-carry-on-column" id="c_qlM-info-leg-1">
# <div class="container">
# <div class="section select-leg" id="c_qlM-info-leg-1-select-leg-column">
# <div class="select-leg-checkbox" id="c_qlM-info-leg-1-select-leg-wrapper">
# <div class="StyleJamCheckbox _bd">
# <input aria-checked="false" aria-disabled="false" aria-label="Show results with this flight only" class="_b _iB _Ir _dc" data-switch-info='{"presentation":"MUTED"}' id="c_qlM-info-leg-1-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="_bd _L _M _m _N _kM _R5 _bg _ej _e _bj _br3 _bm _bp _br0 _7D _dT _br1 _ds _br2 _bv _bU _ga _PM _bgV _bsh _bsi _x2" id="c_qlM-info-leg-1-select-leg-checkbox-icon"></div>
# <label class="_bd _a _Sw _Sx _e _b1 _Sv _z4 _bsj _br4" data-name="specleg" for="c_qlM-info-leg-1-select-leg-checkbox" id="c_qlM-info-leg-1-select-leg-checkbox-label"></label>
# </div>
# </div>
# </div>
# <div class="section carrier">
# <img alt="Etihad Airways logo" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="section times">
# <div class="top">
# <span class="time-pair"> <span class="depart-time base-time">8:30 </span>
# <span class="time-meridiem meridiem">pm</span>
# </span>
# <span class="sep">—</span>
# <span class="time-pair">
# <span class="arrival-time base-time">4:55 </span>
# <span class="time-meridiem meridiem">pm</span>
# <span class="adendum" title="Flight lands the next day">+1</span>
# </span>
# </div>
# <div class="bottom">Etihad Airways</div> </div>
# <div class="section stops">
# <div class="top">
# 1 stop </div>
# <div class="bottom">
# <span class="js-layover" title="12h 35m layover, &lt;b&gt;Abu Dhabi Intl&lt;/b&gt;">AUH</span> </div>
# </div>
# <div class="section duration">
# <div class="top">30h 55m</div>
# <div class="bottom">
# <span>AMD</span>
# <span class="sep">&amp;dash;</span>
# <span>IAD</span>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ol>
# </div>
# </div>
# </div>
# <div class="col-price result-column" id="c_qlM-priceSection">
# <div class="Flights-Results-FlightPriceSection right-alignment sleek" id="c_qlM-price">
# <div class="top-row">
# <div class="left-column">
# <div class="Flights-Results-FlightFeeIcons _v" id="c_qlM-price-flight-fee-icons">
# <div class="_0T _A _0V _N3 _0X _0Z _bZW _bZX _dT _bZY _bZZ _bU _bZ0 _bZ1 _kM _Km _FP _ds _fx _fw _s _Av _ga _x _kh _bZ3" id="c_qlM-price-flight-fee-icons-carryOnBags">
# <div class="_k _O _QB _bfv">
# <svg class="" fill="currentColor" height="10" viewbox="0 0 9 10" width="9" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-carry-on-bag"></use></svg> </div>
# <div class="_k _o _QB _bcW">
# 1
# </div>
# </div>
# <div class="_0T _A _0V _N3 _0X _0Z _bZW _bZX _dT _bZY _bZZ _bU _bZ0 _bZ1 _kM _Km _FP _ds _fx _fw _s _Av _ga _x _kh _bZ3" id="c_qlM-price-flight-fee-icons-checkedBags">
# <div class="_k _O _QB _mi">
# <svg class="_z" fill="currentColor" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-checked-bag_z"></use></svg> </div>
# <div class="_k _o _QB _bcW">
# 2
# </div>
# </div>
# </div>
# </div>
# <div class="Common-Results-ResultOptionsMenu Theme-grey _uN _eQ _g2 _bg5" id="m7Ao">
# <button aria-label="More options" class="_a _A _r _s _v _z _wD Button-No-Standard-Style" id="m7Ao-menu-trigger" title="More options">
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# </button>
# <div class="Common-Widgets-Tip-ToolTip" id="m7Ao-menu-trigger-rendered-content">
# <div class="_A _q _v _fR _Gr _r0 _c1 _c2 _n">
# <div class="_r _gL _v _g2">
# <div class="Common-Trips-ResultItemSaveToTrips row-item grey" id="m7Ao-save">
# <a aria-label="Watch flight" aria-pressed="false" class="layer-content watchlist-style" href="javascript:void(0)" id="m7Ao-save-save" role="button">
# <div class="icon icon-filled">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 0H5C3.896 0 3 .895 3 2v22l9-8 9 8V2c0-1.105-.896-2-2-2zm-7.757 12L7 7.757l1.414-1.414 2.828 2.828 4.95-4.95 1.414 1.415L11.243 12z"></path></svg> </div>
# <div class="icon icon-outline">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 2v17.546l-7-6.222-7 6.222V2h14m0-2H5C3.896 0 3 .895 3 2v22l9-8 9 8V2c0-1.105-.896-2-2-2z"></path></svg> </div>
# <span class="title saveLinkText" id="m7Ao-save-title">
# Watch flight
# </span>
# </a>
# </div>
# </div>
# <div class="_r _gL _v _g2 _bp _bo _dT">
# <a aria-haspopup="true" aria-label="Share" class="Common-Results-ShareLink Icon-default row-item grey" href="javascript:void(0)" id="m7Ao-share" role="button">
# <div class="shareIcon" id="m7Ao-share-icon">
# <svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g transform="translate(.49 .49)"><ellipse cx="13.935" cy="3.036" rx="3.065" ry="3.036"></ellipse><ellipse cx="3.065" cy="9.107" rx="3.065" ry="3.036"></ellipse><ellipse cx="13.935" cy="13.964" rx="3.065" ry="3.036"></ellipse><path d="M4.94 6.987l6.567-3.492.749 1.408-6.568 3.492zM5.312 10.97l6.568 3.492.748-1.408L6.06 9.562z"></path></g></svg> </div>
# <div class="shareLabel" id="m7Ao-share-label">
# Share
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="booking" id="c_qlM-price-bookingSection">
# <div class="multibook-dropdown">
# <div class="Common-Booking-VerticalMultiBookDropdown Flights-Booking-FlightVerticalMultiBookDropdown align-right" id="c_qlM-price-mb">
# <div class="above-button" id="c_qlM-price-mb-above-button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider split-provider featured-provider multi-row Theme-featured-large" id="c_qlM-price-mb-aE068a15dcca8E1322b17bc8a">
# <a aria-label="$1743 from Hacker Fare" class="booking-link" href="javascript:void(0)" id="c_qlM-price-mb-aE068a15dcca8E1322b17bc8a-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $1743 </span>
# <span class="providerName option-text">
# Hacker Fare
# </span>
# </a>
# </div>
# </div>
# <div class="above-button">
# </div>
# <div class="keel-grid multibookGrid" id="c_qlM-price-mb-dropdown-grid" role="listbox">
# <div class="col col-best ">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-m bookingButton " id="c_qlM-price-mb-best" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider split-provider featured-provider Theme-button-small" id="c_qlM-price-mb-bE068a15dcca8E1322b17bc8a">
# <a aria-label="View Deal" class="booking-link" href="javascript:void(0)" id="c_qlM-price-mb-bE068a15dcca8E1322b17bc8a-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# View Deal
# </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="fare-family">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="detailsWrapper" id="c_qlM-detailsWrapper">
# <div class="detailsContent detailsContainer" id="c_qlM-detailsContent">
# <div class="Flights-Results-FlightResultDetails Flights-Results-FlightResultDetailsV3 tab-refresh" id="c_qlM-details">
# <section aria-expanded="true" class="details-section overviewSection" data-tab="overview" id="c_qlM-details-leg-details" role="tabpanel">
# <div class="section-content">
# <div class="Flights-Results-FlightLegDetails" id="Sa2G">
# <div class="header">
# <div class="spec-leg left">
# <span class="leg-filter-checkbox">
# <span class="checkbox-wrapper" id="Sa2G-select-leg-wrapper">
# <div class="Common-Widgets-Checkbox-Checkbox select-leg-checkbox disable-mouseout-animation size-m ">
# <input aria-checked="false" aria-disabled="false" aria-labelledby="Sa2G-select-leg-checkbox-label" id="Sa2G-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="icon" id="Sa2G-select-leg-checkbox-icon"></div>
# <label class="label" data-name="specleg" for="Sa2G-select-leg-checkbox" id="Sa2G-select-leg-checkbox-label">Depart</label>
# </div>
# </span>
# </span>
# </div>
# <div class="airports left">
# <span class="origin-destination">
# IAD - AMD
# </span>
# </div>
# <div class="times right">
# <span class="duration">25h 05m</span>
# </div>
# </div>
# <div class="content-card">
# <div class="segment-row" data-flightnumber="38">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Thu, Dec 20
# </div>
# <div class="arrival-date-warning">
# Lands Fri, Dec 21 </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Saudia" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/SV.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default2.png&amp;_v=9fa4155614c7db822d29db2c77176c2486e7dd51"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">5:00 pm</span>
# —
# <span class="time">1:10 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Washington</span>
# </span>
# -
# <span class="destination">
# <span class="city">Riyadh</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 12h 10m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="rBrF">
# <div class="keel-grid iconGrid" id="rBrF-icons">
# <div class="col-icon">
# <div class="item code-w"></div>
# </div>
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Saudia 38 · Wide-body jet · Boeing 777-300 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="xPb-" tabindex="0">
# <div class="keel-grid layoverGrid ">
# <div class="col-10-12">
# <div class="layoverText " id="xPb--layover-text">
# Change planes in Riyadh (RUH)
# </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">2h 50m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="510">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Fri, Dec 21
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Saudia" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/SV.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default2.png&amp;_v=9fa4155614c7db822d29db2c77176c2486e7dd51"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">4:00 pm</span>
# —
# <span class="time">5:15 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Riyadh</span>
# </span>
# -
# <span class="destination">
# <span class="city">Kuwait City</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 1h 15m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="c0akb">
# <div class="keel-grid iconGrid" id="c0akb-icons">
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Saudia 510 · Narrow-Body Jet · Airbus A320-100/200 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="R6_F" tabindex="0">
# <div class="keel-grid layoverGrid ">
# <div class="col-10-12">
# <div class="layoverText " id="R6_F-layover-text">
# Change planes in Kuwait City (KWI)
# </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">2h 50m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="124">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Fri, Dec 21
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Air Arabia" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/G9.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=66058fe7a2e5252993e4335a27a50116b16f927d"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">8:05 pm</span>
# —
# <span class="time">10:40 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Kuwait City</span>
# </span>
# -
# <span class="destination">
# <span class="city">Sharjah</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 1h 35m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="c8GpZ">
# <div class="keel-grid iconGrid" id="c8GpZ-icons">
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Air Arabia 124 · Narrow-Body Jet · Airbus A320-100/200 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="c-_SM" tabindex="0">
# <div class="keel-grid layoverGrid ">
# <div class="col-10-12">
# <div class="layoverText " id="c-_SM-layover-text">
# Change planes in Sharjah (SHJ)
# </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">2h 00m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="484">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Sat, Dec 22
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid last" tabindex="0">
# <div class="icon-column">
# <img alt="Air Arabia" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/G9.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=66058fe7a2e5252993e4335a27a50116b16f927d"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">12:40 am</span>
# —
# <span class="time">4:35 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Sharjah</span>
# </span>
# -
# <span class="destination">
# <span class="city">Ahmedabad</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 2h 25m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="Wgs_">
# <div class="keel-grid iconGrid" id="Wgs_-icons">
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Air Arabia 484 · Narrow-Body Jet · Airbus A320-100/200 </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-content">
# <div class="Flights-Results-FlightLegDetails" id="c4rwf">
# <div class="header">
# <div class="spec-leg left">
# <span class="leg-filter-checkbox">
# <span class="checkbox-wrapper" id="c4rwf-select-leg-wrapper">
# <div class="Common-Widgets-Checkbox-Checkbox select-leg-checkbox disable-mouseout-animation size-m ">
# <input aria-checked="false" aria-disabled="false" aria-labelledby="c4rwf-select-leg-checkbox-label" id="c4rwf-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="icon" id="c4rwf-select-leg-checkbox-icon"></div>
# <label class="label" data-name="specleg" for="c4rwf-select-leg-checkbox" id="c4rwf-select-leg-checkbox-label">Return</label>
# </div>
# </span>
# </span>
# </div>
# <div class="airports left">
# <span class="origin-destination">
# AMD - IAD
# </span>
# </div>
# <div class="times right">
# <span class="duration">30h 55m</span>
# </div>
# </div>
# <div class="content-card">
# <div class="segment-row" data-flightnumber="227">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Sun, Jan 27
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Etihad Airways" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">8:30 pm</span>
# —
# <span class="time">10:25 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Ahmedabad</span>
# </span>
# -
# <span class="destination">
# <span class="city">Abu Dhabi</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 3h 25m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="c7wnl">
# <div class="keel-grid iconGrid" id="c7wnl-icons">
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Etihad Airways 227 · Narrow-Body Jet · Airbus A320-100/200 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="c-LaA" tabindex="0">
# <div class="keel-grid layoverGrid warn">
# <div class="col-10-12">
# <div class="layoverText " id="c-LaA-layover-text">
# Change planes in Abu Dhabi (AUH)
# </div>
# <div class="layoverWarning ">
# Long layover </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">12h 34m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="131">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Mon, Jan 28
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid last" tabindex="0">
# <div class="icon-column">
# <img alt="Etihad Airways" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EY.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=1713af105e76d3b5232bb65f7343eb57d991254a"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">11:00 am</span>
# —
# <span class="time">4:55 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Abu Dhabi</span>
# </span>
# -
# <span class="destination">
# <span class="city">Washington</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 14h 55m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="VWAn">
# <div class="keel-grid iconGrid" id="VWAn-icons">
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Etihad Airways 131 · Wide-body jet · Boeing 787-9 </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section aria-expanded="true" class="details-section bookingSection" data-tab="rates" id="c_qlM-details-rates" role="tabpanel">
# <div class="Flights-Results-FlightRatesTable Flights-Results-FlightRatesTableV3 carry-on-design" id="G6rd">
# <header class="main-header">
# <h3 class="title left">
# Booking Options </h3>
# </header>
# <section aria-readonly="true" class="table-section content-card" role="treegrid">
# <header class="rates-table-header">
# <div class="Flights-Results-FlightRatesTableHeader Flights-Results-FlightRatesTableHeaderV2 " id="FCRY" role="row">
# <div class="cell header-cell logo end-left-alignment" role="rowheader">
# <div class="header-cell-heading">
# Booking Site </div>
# </div>
# <div class="cell header-cell cabin" role="rowheader">
# <div class="header-cell-icon">
# <span class="cabin-icon">
# <svg fill="currentColor" height="19" viewbox="-0.5 0 15 19" width="15" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-seat-class"></use></svg> </span>
# </div>
# <div class="header-cell-heading">
# Class </div>
# </div>
# <div class="cell header-cell baggage-fees" role="rowheader">
# <div class="header-cell-icon">
# <svg class="" fill="currentColor" height="10" viewbox="0 0 9 10" width="9" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-carry-on-bag"></use></svg> </div>
# <div class="header-cell-heading">
# Carry-On Bag </div>
# </div>
# <div class="cell header-cell baggage-fees" role="rowheader">
# <div class="header-cell-icon">
# <svg fill="currentColor" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-checked-bag"></use></svg> </div>
# <div class="header-cell-heading">
# Checked Bag </div>
# </div>
# <div class="cell header-cell booking-total" role="rowheader">
# <div class="header-cell-icon">
# <svg height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-price-tag-filled"></use></svg> </div>
# <div class="header-cell-heading">
# You Pay </div>
# </div>
# </div>
# </header>
# <div class="provider-tables">
# <div aria-expanded="true" class="ratesTable table-panel" id="G6rd-e" role="tabpanel">
# <ul class="provider-list ratesTable-e" data-category="e" role="rowgroup">
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-0" id="c9qoI" role="row">
# <div class="cell logo end-left-alignment hacker" role="gridcell">
# <span>
# Hacker Fare<sup>1</sup> Kiwi.com + Etihad Airways
# </span>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="BwIi" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="dgfk" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="c9qoI-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider split-provider featured-provider Theme-button-small" id="gzW9">
# <a aria-label="$1743" class="booking-link" href="javascript:void(0)" id="gzW9-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $1743
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </section>
# </div>
# </section>
# <div id="SxQu"></div>
# </div>
# </div>
# </div>
# <div id="Q8WU"></div>
# </div>
# </div>
# <div aria-describedby="BI2q-describedby" aria-label="Best flight number 2: $2332 from KAYAK." class="Base-Results-HorizonResult Flights-Results-FlightResultItem phoenix-rising get-in-formation sleek rp-contrast " data-resultid="0b7d1d539dd246c787fbcfeb36fe57e1" id="BI2q" page-idx="0" tabbable="" tabindex="0">
# <nav class="aria-controls">
# <p id="BI2q-describedby" style="display: none"> Leg 1: Provided by Qatar Airways. Departs from Washington, DC - Dulles Intl on 12/20 at 6:35 pm, lands in Ahmedabad, India - Ahmedabad on 12/22 at 2:15 am. 1 stop (DOH). Total duration: 21h 10m. Leg 2: Provided by Qatar Airways. Departs from Ahmedabad, India - Ahmedabad on 1/27 at 3:40 am, lands in Washington, DC - Dulles Intl on 1/27 at 3:00 pm. 1 stop (DOH). Total duration: 21h 50m. We think you'll like these flights based on their duration, price, number of stops and carrier type.</p>
# <a href="javascript:void(0)" id="BI2q-skip">Go to next result</a>
# <a href="#BI2q-price">Go to price</a>
# <a href="#BI2q-info">Go to flight info</a>
# <div aria-labelledby="BI2q-aria-details-open" class="Flights-Results-DetailsLink " id="BI2q-aria-details">
# <a aria-pressed="false" class="detailsToggle" href="javascript:void(0)" id="BI2q-aria-details-toggleMore" role="button">
# <span class="openText" id="BI2q-aria-details-open">See details</span>
# <span class="closeText" id="BI2q-aria-details-close">Hide details</span>
# </a>
# </div>
# </nav>
# <div class="resultWrapper">
# <div class="resultInner">
# <div class="inner-grid keel-grid">
# <div class="col-info result-column">
# <div class="mainInfo" id="BI2q-mainInfo">
# <div class="Flights-Results-ResultInfo multiple-legs" id="BI2q-info">
# <ol class="flights">
# <li class="flight with-gutter">
# <div class="Flights-Results-LegInfo Flights-Results-LegInfoSleek no-carry-on-column" id="BI2q-info-leg-0">
# <div class="container">
# <div class="section select-leg" id="BI2q-info-leg-0-select-leg-column">
# <div class="select-leg-checkbox" id="BI2q-info-leg-0-select-leg-wrapper">
# <div class="StyleJamCheckbox _bd">
# <input aria-checked="false" aria-disabled="false" aria-label="Show results with this flight only" class="_b _iB _Ir _dc" data-switch-info='{"presentation":"MUTED"}' id="BI2q-info-leg-0-select-leg-checkbox" name="specleg" type="checkbox" value="">
# <div class="_bd _L _M _m _N _kM _R5 _bg _ej _e _bj _br3 _bm _bp _br0 _7D _dT _br1 _ds _br2 _bv _bU _ga _PM _bgV _bsh _bsi _x2" id="BI2q-info-leg-0-select-leg-checkbox-icon"></div>
# <label class="_bd _a _Sw _Sx _e _b1 _Sv _z4 _bsj _br4" data-name="specleg" for="BI2q-info-leg-0-select-leg-checkbox" id="BI2q-info-leg-0-select-leg-checkbox-label"></label>
# </input></div>
# </div>
# </div>
# <div class="section carrier">
# <img alt="Qatar Airways logo" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/QR.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default2.png&amp;_v=bd948c597e491c03c2fa0270e8bed3e0865fd049"/>
# </div>
# <div class="section times">
# <div class="top">
# <span class="time-pair"> <span class="depart-time base-time">6:35 </span>
# <span class="time-meridiem meridiem">pm</span>
# </span>
# <span class="sep">—</span>
# <span class="time-pair">
# <span class="arrival-time base-time">2:15 </span>
# <span class="time-meridiem meridiem">am</span>
# <span class="adendum" title="Flight lands 2 days later">+2</span>
# </span>
# </div>
# <div class="bottom">Qatar Airways</div> </div>
# <div class="section stops">
# <div class="top">
# 1 stop </div>
# <div class="bottom">
# <span class="js-layover" title="5h 30m layover, &lt;b&gt;Doha Hamad International&lt;/b&gt;">DOH</span> </div>
# </div>
# <div class="section duration">
# <div class="top">21h 10m</div>
# <div class="bottom">
# <span>IAD</span>
# <span class="sep">&amp;dash;</span>
# <span>AMD</span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="flight ">
# <div class="Flights-Results-LegInfo Flights-Results-LegInfoSleek no-carry-on-column" id="BI2q-info-leg-1">
# <div class="container">
# <div class="section select-leg" id="BI2q-info-leg-1-select-leg-column">
# <div class="select-leg-checkbox" id="BI2q-info-leg-1-select-leg-wrapper">
# <div class="StyleJamCheckbox _bd">
# <input aria-checked="false" aria-disabled="false" aria-label="Show results with this flight only" class="_b _iB _Ir _dc" data-switch-info='{"presentation":"MUTED"}' id="BI2q-info-leg-1-select-leg-checkbox" name="specleg" type="checkbox" value="">
# <div class="_bd _L _M _m _N _kM _R5 _bg _ej _e _bj _br3 _bm _bp _br0 _7D _dT _br1 _ds _br2 _bv _bU _ga _PM _bgV _bsh _bsi _x2" id="BI2q-info-leg-1-select-leg-checkbox-icon"></div>
# <label class="_bd _a _Sw _Sx _e _b1 _Sv _z4 _bsj _br4" data-name="specleg" for="BI2q-info-leg-1-select-leg-checkbox" id="BI2q-info-leg-1-select-leg-checkbox-label"></label>
# </input></div>
# </div>
# </div>
# <div class="section carrier">
# <img alt="Qatar Airways logo" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/QR.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default2.png&amp;_v=bd948c597e491c03c2fa0270e8bed3e0865fd049"/>
# </div>
# <div class="section times">
# <div class="top">
# <span class="time-pair"> <span class="depart-time base-time">3:40 </span>
# <span class="time-meridiem meridiem">am</span>
# </span>
# <span class="sep">—</span>
# <span class="time-pair">
# <span class="arrival-time base-time">3:00 </span>
# <span class="time-meridiem meridiem">pm</span>
# </span>
# </div>
# <div class="bottom">Qatar Airways</div> </div>
# <div class="section stops">
# <div class="top">
# 1 stop </div>
# <div class="bottom">
# <span class="js-layover" title="3h layover, &lt;b&gt;Doha Hamad International&lt;/b&gt;">DOH</span> </div>
# </div>
# <div class="section duration">
# <div class="top">21h 50m</div>
# <div class="bottom">
# <span>AMD</span>
# <span class="sep">&amp;dash;</span>
# <span>IAD</span>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ol>
# </div>
# </div>
# </div>
# <div class="col-price result-column" id="BI2q-priceSection">
# <div class="Flights-Results-FlightPriceSection right-alignment sleek" id="BI2q-price">
# <div class="top-row">
# <div class="left-column">
# <div class="Flights-Results-FlightFeeIcons _v" id="BI2q-price-flight-fee-icons">
# <div class="_0T _A _0V _N3 _0X _0Z _bZW _bZX _dT _bZY _bZZ _bU _bZ0 _bZ1 _kM _Km _FP _ds _fx _fw _s _Av _ga _x _kh _bZ3" id="BI2q-price-flight-fee-icons-carryOnBags">
# <div class="_k _O _QB _bfv">
# <svg class="" fill="currentColor" height="10" viewbox="0 0 9 10" width="9" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-carry-on-bag"></use></svg> </div>
# <div class="_k _o _QB _bcW">
# 1
# </div>
# </div>
# <div class="_0T _A _0V _N3 _0X _0Z _bZW _bZX _dT _bZY _bZZ _bU _bZ0 _bZ1 _kM _Km _FP _ds _fx _fw _s _Av _ga _x _kh _bZ3" id="BI2q-price-flight-fee-icons-checkedBags">
# <div class="_k _O _QB _mi">
# <svg class="_z" fill="currentColor" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-checked-bag_z"></use></svg> </div>
# <div class="_k _o _QB _bcW">
# 2
# </div>
# </div>
# </div>
# </div>
# <div class="Common-Results-ResultOptionsMenu Theme-grey _uN _eQ _g2 _bg5" id="jjS1">
# <button aria-label="More options" class="_a _A _r _s _v _z _wD Button-No-Standard-Style" id="jjS1-menu-trigger" title="More options">
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# </button>
# <div class="Common-Widgets-Tip-ToolTip" id="jjS1-menu-trigger-rendered-content">
# <div class="_A _q _v _fR _Gr _r0 _c1 _c2 _n">
# <div class="_r _gL _v _g2">
# <div class="Common-Trips-ResultItemSaveToTrips row-item grey" id="jjS1-save">
# <a aria-label="Watch flight" aria-pressed="false" class="layer-content watchlist-style" href="javascript:void(0)" id="jjS1-save-save" role="button">
# <div class="icon icon-filled">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 0H5C3.896 0 3 .895 3 2v22l9-8 9 8V2c0-1.105-.896-2-2-2zm-7.757 12L7 7.757l1.414-1.414 2.828 2.828 4.95-4.95 1.414 1.415L11.243 12z"></path></svg> </div>
# <div class="icon icon-outline">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 2v17.546l-7-6.222-7 6.222V2h14m0-2H5C3.896 0 3 .895 3 2v22l9-8 9 8V2c0-1.105-.896-2-2-2z"></path></svg> </div>
# <span class="title saveLinkText" id="jjS1-save-title">
# Watch flight
# </span>
# </a>
# </div>
# </div>
# <div class="_r _gL _v _g2 _bp _bo _dT">
# <a aria-haspopup="true" aria-label="Share" class="Common-Results-ShareLink Icon-default row-item grey" href="javascript:void(0)" id="jjS1-share" role="button">
# <div class="shareIcon" id="jjS1-share-icon">
# <svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g transform="translate(.49 .49)"><ellipse cx="13.935" cy="3.036" rx="3.065" ry="3.036"></ellipse><ellipse cx="3.065" cy="9.107" rx="3.065" ry="3.036"></ellipse><ellipse cx="13.935" cy="13.964" rx="3.065" ry="3.036"></ellipse><path d="M4.94 6.987l6.567-3.492.749 1.408-6.568 3.492zM5.312 10.97l6.568 3.492.748-1.408L6.06 9.562z"></path></g></svg> </div>
# <div class="shareLabel" id="jjS1-share-label">
# Share
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="booking" id="BI2q-price-bookingSection">
# <div class="multibook-dropdown">
# <div class="Common-Booking-VerticalMultiBookDropdown Common-Booking-CategorizedVerticalMultiBookDropdown align-right with-dropdown" id="BI2q-price-mb">
# <div class="above-button" id="BI2q-price-mb-above-button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider whisky-provider featured-provider multi-row Theme-featured-large" id="BI2q-price-mb-aE-144d6d94d65">
# <a aria-label="$2332 from KAYAK" class="booking-link" href="/book/flight?code=EdCCLH_bDe.FEHQgqOye8l9cbIfBvnkohRd8SgVjFCz.233184.0b7d1d539dd246c787fbcfeb36fe57e1&amp;h=03c1c9ddccff&amp;_kw_pbranded=true&amp;sub=E-144d6d94d65" id="BI2q-price-mb-aE-144d6d94d65-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2332 </span>
# <span class="providerName option-text">
# KAYAK
# </span>
# </a>
# </div>
# </div>
# <div class="above-button">
# </div>
# <div class="keel-grid multibookGrid" id="BI2q-price-mb-dropdown-grid" role="listbox">
# <div class="col col-best ">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-m bookingButton whisky-provider" id="BI2q-price-mb-best" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small whisky-provider featured-provider " id="BI2q-price-mb-bE-144d6d94d65">
# <a aria-label="View Deal" class="booking-link" href="/book/flight?code=EdCCLH_bDe.FEHQgqOye8l9cbIfBvnkohRd8SgVjFCz.233184.0b7d1d539dd246c787fbcfeb36fe57e1&amp;h=03c1c9ddccff&amp;_kw_pbranded=true&amp;sub=E-144d6d94d65" id="BI2q-price-mb-bE-144d6d94d65-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# View Deal
# </span>
# </a>
# </div>
# </div>
# </div>
# <div class="col-dropdown whisky-provider">
# <a aria-controls="BI2q-price-mb-dropdown_content" aria-expanded="false" aria-haspopup="true" aria-label="" aria-owns="BI2q-price-mb-dropdown_content" aria-pressed="false" class="Common-Widgets-Dropdown-DropdownDialog ui-button Button-Gradient-End multibook size-m iconOnly" data-alignment="right" data-expandto="BI2q-price-mb-dropdown-grid" href="javascript:void(0)" id="BI2q-price-mb-dropdown" role="button">
# <div class="label">
# </div>
# <div class="placeholder">
# </div>
# <div class="icon">
# <svg class="" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.35" viewbox="0 0 8 5" xmlns="http://www.w3.org/2000/svg"><path d="M7 1.053L4.027 4 1 1" fill="none" stroke="currentColor"></path></svg> </div>
# </a>
# <div aria-expanded="false" class="Common-Widgets-Dropdown-DropdownDialog-Content Common-Booking-VerticalMultiBookDropdown-Content slide-down-animation Common-Booking-CategorizedVerticalMultiBookDropdownList-Content get-in-formation R9-Overlay animate-top-right" data-dropdown-owner="BI2q-price-mb" id="BI2q-price-mb-dropdown_content" role="dialog">
# <div class="animation-container">
# <ul class="option-list" id="BI2q-price-mb-list">
# <div class="Common-Booking-CategorizedVerticalMultiBookDropdownList" id="BI2q-price-mb-dd">
# <div class="option-categories">
# <div class="category-label category-whisky">Book on KAYAK</div>
# <ul aria-label="Book on KAYAK" class="option-list whisky-list">
# <li>
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-dropdown-item whisky-provider featured-provider " id="BI2q-price-mb-dd-E-144d6d94d65">
# <a aria-label="$2332 from KAYAK" class="booking-link" href="/book/flight?code=EdCCLH_bDe.FEHQgqOye8l9cbIfBvnkohRd8SgVjFCz.233184.0b7d1d539dd246c787fbcfeb36fe57e1&amp;h=03c1c9ddccff&amp;_kw_pbranded=true&amp;sub=E-144d6d94d65" id="BI2q-price-mb-dd-E-144d6d94d65-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2332 </span>
# <span class="providerName option-text">
# KAYAK
# </span>
# </a>
# </div>
# </li>
# </ul>
# <div class="category-label category-external">More Booking Options</div>
# <ul aria-label="More Booking Options" class="option-list external-list">
# <li>
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-dropdown-item" id="BI2q-price-mb-dd-E-10d6b784877">
# <a aria-label="$2332 from Priceline" class="booking-link" href="/book/flight?code=EdCCLH_bDe.JZO1f6NT9B8-ciubBqDvug.233184.0b7d1d539dd246c787fbcfeb36fe57e1&amp;h=36732eb684dd&amp;sub=E-10d6b784877" id="BI2q-price-mb-dd-E-10d6b784877-booking-link" role="option" tabindex="0" target="_blank">
# ...
# 1h 15m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="ixrp">
# <div class="keel-grid iconGrid" id="ixrp-icons">
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Saudia 510 · Narrow-Body Jet · Airbus A320-100/200 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="c2cTy" tabindex="0">
# <div class="keel-grid layoverGrid ">
# <div class="col-10-12">
# <div class="layoverText " id="c2cTy-layover-text">
# Change planes in Kuwait City (KWI)
# </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">2h 50m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="124">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Fri, Dec 21
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Air Arabia" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/G9.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=66058fe7a2e5252993e4335a27a50116b16f927d"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">8:05 pm</span>
# —
# <span class="time">10:40 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Kuwait City</span>
# </span>
# -
# <span class="destination">
# <span class="city">Sharjah</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 1h 35m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="MDNT">
# <div class="keel-grid iconGrid" id="MDNT-icons">
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Air Arabia 124 · Narrow-Body Jet · Airbus A320-100/200 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="q8ci" tabindex="0">
# <div class="keel-grid layoverGrid ">
# <div class="col-10-12">
# <div class="layoverText " id="q8ci-layover-text">
# Change planes in Sharjah (SHJ)
# </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">2h 00m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="484">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Sat, Dec 22
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid last" tabindex="0">
# <div class="icon-column">
# <img alt="Air Arabia" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/G9.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default3.png&amp;_v=66058fe7a2e5252993e4335a27a50116b16f927d"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">12:40 am</span>
# —
# <span class="time">4:35 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Sharjah</span>
# </span>
# -
# <span class="destination">
# <span class="city">Ahmedabad</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 2h 25m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="i5mA">
# <div class="keel-grid iconGrid" id="i5mA-icons">
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Air Arabia 484 · Narrow-Body Jet · Airbus A320-100/200 </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-content">
# <div class="Flights-Results-FlightLegDetails" id="FO4Q">
# <div class="header">
# <div class="spec-leg left">
# <span class="leg-filter-checkbox">
# <span class="checkbox-wrapper" id="FO4Q-select-leg-wrapper">
# <div class="Common-Widgets-Checkbox-Checkbox select-leg-checkbox disable-mouseout-animation size-m ">
# <input aria-checked="false" aria-disabled="false" aria-labelledby="FO4Q-select-leg-checkbox-label" id="FO4Q-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="icon" id="FO4Q-select-leg-checkbox-icon"></div>
# <label class="label" data-name="specleg" for="FO4Q-select-leg-checkbox" id="FO4Q-select-leg-checkbox-label">Return</label>
# </div>
# </span>
# </span>
# </div>
# <div class="airports left">
# <span class="origin-destination">
# AMD - BWI
# </span>
# </div>
# <div class="times right">
# <span class="duration">25h 08m</span>
# </div>
# </div>
# <div class="content-card">
# <div class="segment-row" data-flightnumber="6411">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Sun, Jan 27
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Air Canada" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/AC.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=c33c075a04cbaa27b8b0e6fc200aeb03f4663797"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">6:50 pm</span>
# —
# <span class="time">8:30 pm</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Ahmedabad</span>
# </span>
# -
# <span class="destination">
# <span class="city">New Delhi</span>
# </span>
# -
# <span class="seatsRemaining modal-min-hide">
# 4 seats remain </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 1h 40m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="Htq9">
# <div class="keel-grid iconGrid" id="Htq9-icons">
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Air Canada 6411 · Narrow-Body Jet · Airbus A320-100/200 </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="operatorDetails details-subheading">
# Operated by Air India </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="c4iqg" tabindex="0">
# <div class="keel-grid layoverGrid warn">
# <div class="col-10-12">
# <div class="layoverText " id="c4iqg-layover-text">
# Change planes in New Delhi (DEL)
# </div>
# <div class="layoverWarning ">
# Long layover </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">4h 16m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="43">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Mon, Jan 28
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Air Canada" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/AC.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=c33c075a04cbaa27b8b0e6fc200aeb03f4663797"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">12:45 am</span>
# —
# <span class="time">5:05 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">New Delhi</span>
# </span>
# -
# <span class="destination">
# <span class="city">Toronto</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 14h 50m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="g6YU">
# <div class="keel-grid iconGrid" id="g6YU-icons">
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Air Canada 43 · Wide-body jet · Boeing 787-9 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="n4gk" tabindex="0">
# <div class="keel-grid layoverGrid ">
# <div class="col-10-12">
# <div class="layoverText " id="n4gk-layover-text">
# Change planes in Toronto (YYZ)
# </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">2h 59m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="7502">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Mon, Jan 28
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid last" tabindex="0">
# <div class="icon-column">
# <img alt="Air Canada" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/AC.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=c33c075a04cbaa27b8b0e6fc200aeb03f4663797"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">8:05 am</span>
# —
# <span class="time">9:28 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Toronto</span>
# </span>
# -
# <span class="destination">
# <span class="city">Baltimore</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 1h 23m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="c5TW6">
# <div class="keel-grid iconGrid" id="c5TW6-icons">
# <div class="col-icon">
# <div class="item code-w"></div>
# </div>
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Air Canada 7502 · Narrow-Body Jet · Embraer 175 </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="operatorDetails details-subheading">
# Operated by Air Canada Express - Sky Regional </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section aria-expanded="true" class="details-section bookingSection" data-tab="rates" id="c3QM2-details-rates" role="tabpanel">
# <div class="Flights-Results-FlightRatesTable Flights-Results-FlightRatesTableV3 carry-on-design" id="sfkY">
# <header class="main-header">
# <h3 class="title left">
# Booking Options </h3>
# </header>
# <section aria-readonly="true" class="table-section content-card" role="treegrid">
# <header class="rates-table-header">
# <div class="Flights-Results-FlightRatesTableHeader Flights-Results-FlightRatesTableHeaderV2 " id="c36Z0" role="row">
# <div class="cell header-cell logo end-left-alignment" role="rowheader">
# <div class="header-cell-heading">
# Booking Site </div>
# </div>
# <div class="cell header-cell cabin" role="rowheader">
# <div class="header-cell-icon">
# <span class="cabin-icon">
# <svg fill="currentColor" height="19" viewbox="-0.5 0 15 19" width="15" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-seat-class"></use></svg> </span>
# </div>
# <div class="header-cell-heading">
# Class </div>
# </div>
# <div class="cell header-cell baggage-fees" role="rowheader">
# <div class="header-cell-icon">
# <svg class="" fill="currentColor" height="10" viewbox="0 0 9 10" width="9" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-carry-on-bag"></use></svg> </div>
# <div class="header-cell-heading">
# Carry-On Bag </div>
# </div>
# <div class="cell header-cell baggage-fees" role="rowheader">
# <div class="header-cell-icon">
# <svg fill="currentColor" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-checked-bag"></use></svg> </div>
# <div class="header-cell-heading">
# Checked Bag </div>
# </div>
# <div class="cell header-cell booking-total" role="rowheader">
# <div class="header-cell-icon">
# <svg height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-price-tag-filled"></use></svg> </div>
# <div class="header-cell-heading">
# You Pay </div>
# </div>
# </div>
# </header>
# <div class="provider-tables">
# <div aria-expanded="true" class="ratesTable table-panel" id="sfkY-e" role="tabpanel">
# <ul class="provider-list ratesTable-e" data-category="e" role="rowgroup">
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-0" id="uJCw" role="row">
# <div class="cell logo end-left-alignment hacker" role="gridcell">
# <span>
# Hacker Fare<sup>1</sup> Kiwi.com + Air Canada
# </span>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="ay3c" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# <a class="bfcAdd addFee" data-filter="bfc" href="javascript:void(0)">
# add </a>
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="E4-r" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="uJCw-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider split-provider featured-provider Theme-button-small" id="AjZd">
# <a aria-label="$2209" class="booking-link" href="javascript:void(0)" id="AjZd-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $2209
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </section>
# </div>
# </section>
# <div id="Z414"></div>
# </div>
# </div>
# </div>
# <div id="kXAe"></div>
# </div>
# </div>
# </div>
# </div>
# <div id="FlightResultsDataLayer"></div>
# ;
