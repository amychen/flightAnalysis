# %%
import requests
from bs4 import BeautifulSoup
from lxml import html
import json
import pandas
import re

# %%
url = 'https://www.kayak.com'
r = requests.get(url)
layer1Cookies = r.cookies

url2 = url + '/s/horizon/flights/results/FlightSearchPoll'

origin_code = 'WAS'
origin_location = 'WASHINGTON'
destination_code = 'AMD'
destination_location = 'Ahmedabad'
depart_date = '2018-12-20'
return_date = '2019-01-27'

referer = 'https://www.kayak.com/flights/'+origin_code+'-'+destination_code+'/'+depart_date+'/'+return_date
headers = {
    'Host': 'www.kayak.com',
    'User-Agent': 'Chrome/63 (Macintosh; Intel Mac OS X 10.11; rv:57.0) Gecko/20100101 Firefox/57.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': referer,
    'Content-Type': 'application/x-www-form-urlencoded',
    'X-CSRF': 'kAqI1NgGh$DJnEUpiSDOWpdQXzlgAwG8EVOCd$gXO08-hpumC4oNpaOjz15GO_q9a5FdZPonpC2kF4CBYjEPh14',
    'X-RequestId': 'flights#frontdoor#Ag$s9g',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Length': '1094'
}

url3 = 'flights/'+origin_code+'-'+destination_code+'/'+depart_date+'/'+return_date

params1 = {
    'searchId':'',
    'poll':'true',
    'pollNumber':'0',
    'applyFilters':'true',
    'filterState':'',
    'useViewStateFilterState':'false',
    'pageNumber':'1',
    'append':'false',
    'pollingId':'593601',  #interesting. explore further
    'requestReason':'POLL',
    'isSecondPhase':'false',
    'textAndPageLocations':'bottom,right',
    'displayAdPageLocations':'none',
    'existingAds':'false',
    'activeLeg':'-1',
    'view':'list',
    'renderPlusMinusThreeFlex':'false',
    'renderAirlineStopsMatrix':'false',
    'renderFlexHeader':'true',
    'tab':'flights',
    'pageOrigin':'F..FD..M0',
    'src':'',
    'searchingAgain':'',
    'c2s':'',
    'po':'',
    'personality':'',
    'provider':'',
    'isMulticity':'false',
    'flex_category':'exact',
    'depart_date':depart_date,
    'return_date':return_date,
    'oneway':'false',
    'origincode':origin_code,  #change accordingly
    'origin':origin_code, #change accordingly
    'origin_location':origin_location, #change accordingly
    'origin_code':'', #change accordingly
    'nearby_origin':'false',
    'destination':destination_code, #change accordingly
    'destination_location':destination_location, #change accordingly
    'destination_code':'', #change accordingly
    'nearby_destination':'false',
    'countrySearch':'false',
    'depart_date_canon':depart_date, #change accordingly
    'return_date_canon':return_date, #change accordingly
    'travelers':'1',
    'adults':'1',
    'seniors':'0',
    'youth':'0',
    'child':'0',
    'seatInfant':'0',
    'lapInfant':'0',
    'cabin':'e',
    'cabinDisplayType':'Economy',
    'vertical':'flights',
    'url':url3,
    'id':'',
    'navigateToResults':'false',
    'ajaxts':'',
    'scriptsMetadata':'',
    'stylesMetadata':'',
}


result = requests.post(url2, headers = headers, data = params1, cookies = layer1Cookies)
text = result.json()

BeautifulSoup(text['content'], 'html.parser')
# Out:
# <div data-ajax-replace="" id="watchedItemContainer">
# </div>
# <div class="aboveHeaderContainer " data-ajax-replace="" id="aboveHeaderContainer">
# <div class="Flights-Results-FlightAboveHeaderContent FlightAboveHeaderContent" id="LYZ1">
# <div aria-expanded="false" class="flexMatrixWrapper">
# </div>
# <div aria-expanded="false" class="airlineWrapper">
# </div>
# </div>
# </div>
# <div class="aboveResultsContainer" data-ajax-replace="" id="aboveResultsContainer">
# <div class="Flights-Results-FlightAboveResultsContent" id="c55LG">
# </div>
# </div>
# <div id="customTicketHeader">
# </div>
# <div data-ajax-replace="" id="flexHeader">
# <div class="Flights-Results-Filters-FlexDateHeader " id="c1yri">
# <div class="keel-grid flex-grid" id="c1yri-flex-grid">
# <div class="col-1-5 flex-option" data-depart="true" data-difference="-1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="K98M">
# <div>
# <div class="itemTitle">
# <div class="js-title">Depart</div>
# <div class="dow js-subtitle">Dec 19</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="true" data-difference="1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="lxJZ">
# <div>
# <div class="itemTitle">
# <div class="js-title">Depart</div>
# <div class="dow js-subtitle">Dec 21</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="true" data-difference="0">
# <div class="Flights-Results-Filters-FlexDateItem exact empty border" id="AUt6">
# <div>
# <div class="itemTitle">
# <div class="js-title">Exact Dates</div>
# <div class="dow js-subtitle">Dec 20 - Jan 27</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="false" data-difference="-1">
# <div class="Flights-Results-Filters-FlexDateItem empty border" id="Y9e1">
# <div>
# <div class="itemTitle">
# <div class="js-title">Return</div>
# <div class="dow js-subtitle">Jan 26</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# <div class="col-1-5 flex-option" data-depart="false" data-difference="1">
# <div class="Flights-Results-Filters-FlexDateItem empty" id="bXWz">
# <div>
# <div class="itemTitle">
# <div class="js-title">Return</div>
# <div class="dow js-subtitle">Jan 28</div>
# </div>
# <div class="itemPrice ">
# &amp;dash;&amp;dash;
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Base-Results-ResultsList Flights-Results-FlightResultsList" id="searchResultsList">
# <div id="EqACLXCXSy-1">
# <div aria-label="Advertisement from emirates.com/us: Fly Better to Ahmedabad with Emirates Enjoy free onboard Wi-Fi, gourmet cuisine and up to 3,500 channels of entertainment." class="Common-Kn-Rp-Inline flights phoenix-rising clearfix type-provider rp-contrast" id="inline-1" onclick="R9.events.publish('ecommerce.track', {event: 'inline.ad'});" role="link" tabbable="" tabindex="0">
# <nav class="aria-controls">
# <a href="javascript:void(0)" id="inline-1-skip">Skip this item</a>
# </nav>
# <img alt="" class="inlineAdTracking" src="/k/redirect/tracking?url=$&amp;h=u1UyuH1zHPbbqWSiWjBTEnGHkJo&amp;plid=9930852&amp;searchID=EqACLXCXSy"/>
# <div class="Common-Kn-Rp-FlightInline smart " id="c58iS" onclick="window.open('https://www.kayak.com/s/clickthrough.jsp?ctyp=InlineOpaqueAdBooking&amp;ptyp=F&amp;orig=F..RP..M1&amp;octid=&amp;plid=9930852&amp;cpnid=7040978&amp;pid=EmiratesGlobalUS_FIOAD_US&amp;prv=EmiratesGlobalUS_FIOAD_US&amp;srch=EqACLXCXSy&amp;ploc=US&amp;displayRail=Rslt&amp;rank=1&amp;atype=inline&amp;prc=2502.00&amp;xpExt=&amp;aidExt=&amp;lid=EmiratesGlobalUS_FIOAD_US-EqACLXCXSy&amp;qorig=Airport:WAS&amp;qdest=Airport:AMD&amp;qstart=1545282000000&amp;qend=1548565200000&amp;qtravelers=1&amp;qrooms=0&amp;qow=false&amp;qfcc=e&amp;qdctid=29732&amp;qdac=AMD&amp;qshour=-1&amp;qehour=-1&amp;resid=a4ecca86d86a60e918a2f573a586eb20&amp;bookid=E-14f1d635ea8&amp;seekProv=&amp;qadults=1&amp;qchild=0&amp;qns=false&amp;qnearby=0&amp;qnearbyo=false&amp;qnearbyd=false&amp;qcages=&amp;qinfantseat=0&amp;qinfantlap=0&amp;qsenior=0&amp;pgNum=1©Id=0&amp;iar=1&amp;stid=23945014&amp;ah=5CxYu0_ZziGjx8DZojoMHwdLp8lpqHCL8688czw8x2Q&amp;pj=A9L5911iv57To3NDr9d4xw==')">
# <div class="content-col with-price-groups">
# <div class="icon">
# <img alt="emirates.com/us" src="/kimg/logos/457387a7d143a997.png"/>
# </div>
# <div class="content">
# <div class="inlineAdHeadline">Fly Better to Ahmedabad with Emirates</div>
# <div class="inlineAdDescription no-options">
# <span>Enjoy free onboard Wi-Fi, gourmet cuisine and up to 3,500 channels of entertainment.</span>
# </div>
# <ul class="inlineAdPriceList clearfix hasWideCurrency ">
# <li class="inlineAdPriceRow ">
# <a href="https://www.kayak.com/s/clickthrough.jsp?ctyp=InlineOpaqueAdBooking&amp;ptyp=F&amp;orig=F..RP..M1&amp;octid=&amp;plid=9930852&amp;cpnid=7040978&amp;pid=EmiratesGlobalUS_FIOAD_US&amp;prv=EmiratesGlobalUS_FIOAD_US&amp;srch=EqACLXCXSy&amp;ploc=US&amp;displayRail=Rslt&amp;rank=1&amp;atype=inline&amp;prc=2502.00&amp;xpExt=&amp;aidExt=&amp;lid=EmiratesGlobalUS_FIOAD_US-EqACLXCXSy&amp;qorig=Airport:WAS&amp;qdest=Airport:AMD&amp;qstart=1545282000000&amp;qend=1548565200000&amp;qtravelers=1&amp;qrooms=0&amp;qow=false&amp;qfcc=e&amp;qdctid=29732&amp;qdac=AMD&amp;qshour=-1&amp;qehour=-1&amp;resid=a4ecca86d86a60e918a2f573a586eb20&amp;bookid=E-14f1d635ea8&amp;seekProv=&amp;qadults=1&amp;qchild=0&amp;qns=false&amp;qnearby=0&amp;qnearbyo=false&amp;qnearbyd=false&amp;qcages=&amp;qinfantseat=0&amp;qinfantlap=0&amp;qsenior=0&amp;pgNum=1©Id=0&amp;iar=1&amp;stid=23945014&amp;ah=5CxYu0_ZziGjx8DZojoMHwdLp8lpqHCL8688czw8x2Q&amp;pj=A9L5911iv57To3NDr9d4xw==" onclick="event.cancelBubble = true; if(event.stopPropagation) { event.stopPropagation() };" rel="nofollow" target="_blank">
# <span class="inlineAdPrice">$2502</span>
# <span class="inlineAdStops">1 stop </span>
# <span class="inlineAdSelect hidden">View Deal</span>
# </a>
# </li>
# </ul>
# <div class="inlineAdFooter clean">
# <span>emirates.com/us | </span> <span class="sponsoredTag">Sponsored</span>
# </div>
# </div>
# </div>
# <div class="price-col inlineAdPriceColumn right-alignment">
# <div class="inlineAdSelect">
# <div class="bookitselect">
# <div class="featured-provider">
# <div class="price">
# $2502
# </div>
# <div class="provider-brand">Emirates</div>
# </div>
# <a aria-label="Ad: View deal from emirates.com/us" class="ui-button Button-Gradient" href="javascript:void(0)" onclick="" rel="nofollow" target="">
# <div class="view-deal">
# View Deal </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Flights-Results-BestFlights phoenix-rising" id="RC52">
# <div class="best-flights-list">
# <div class="best-flights-border-container"></div>
# <div class="best-flights-header">
# <span class="title">
# Best Flights
# </span>
# <span class="information" id="RC52-tooltip-icon">
# ⓘ
# </span>
# </div>
# <div aria-describedby="vSsq-describedby" aria-label="Best flight number 1: $2077 from KAYAK." class="Base-Results-HorizonResult Flights-Results-FlightResultItem phoenix-rising sleek rp-contrast " data-resultid="a4ecca86d86a60e918a2f573a586eb20" id="vSsq" page-idx="0" tabbable="" tabindex="0">
# <nav class="aria-controls">
# <p id="vSsq-describedby" style="display: none"> Leg 1: Provided by Emirates. Departs from Washington, DC - Dulles Intl on 12/20 at 10:25 am, lands in Ahmedabad, India - Ahmedabad on 12/22 at 3:00 am. 1 stop (DXB). Total duration: 30h 05m. Leg 2: Provided by Emirates. Departs from Ahmedabad, India - Ahmedabad on 1/27 at 9:35 am, lands in Washington, DC - Dulles Intl on 1/28 at 8:10 am. 1 stop (DXB). Total duration: 33h 05m. We think you'll like these flights based on their duration, price, number of stops and carrier type.</p>
# <a href="javascript:void(0)" id="vSsq-skip">Go to next result</a>
# <a href="#vSsq-price">Go to price</a>
# <a href="#vSsq-info">Go to flight info</a>
# <div aria-labelledby="vSsq-aria-details-open" class="Flights-Results-DetailsLink " id="vSsq-aria-details">
# <a aria-pressed="false" class="detailsToggle" href="javascript:void(0)" id="vSsq-aria-details-toggleMore" role="button">
# <span class="openText" id="vSsq-aria-details-open">See details</span>
# <span class="closeText" id="vSsq-aria-details-close">Hide details</span>
# </a>
# </div>
# </nav>
# <div class="resultWrapper">
# <div class="resultInner">
# <div class="inner-grid keel-grid">
# <div class="col-info result-column">
# <div class="mainInfo" id="vSsq-mainInfo">
# <div class="Flights-Results-ResultInfo multiple-legs" id="vSsq-info">
# <ol class="flights">
# <li class="flight with-gutter">
# <div class="Flights-Results-LegInfo Flights-Results-LegInfoSleek no-carry-on-column" id="vSsq-info-leg-0">
# <div class="container">
# <div class="section select-leg" id="vSsq-info-leg-0-select-leg-column">
# <div class="select-leg-checkbox" id="vSsq-info-leg-0-select-leg-wrapper">
# <div class="StyleJamCheckbox _bd">
# <input aria-checked="false" aria-disabled="false" aria-label="Show results with this flight only" class="_b _iB _Ir _dc" data-switch-info='{"presentation":"MUTED"}' id="vSsq-info-leg-0-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="_bd _L _M _m _N _kM _R5 _bg _ej _e _bj _br3 _bm _bp _br0 _7D _dT _br1 _ds _br2 _bv _bU _ga _PM _bgV _bsh _bsi _x2" id="vSsq-info-leg-0-select-leg-checkbox-icon"></div>
# <label class="_bd _a _Sw _Sx _e _b1 _Sv _z4 _bsj _br4" data-name="specleg" for="vSsq-info-leg-0-select-leg-checkbox" id="vSsq-info-leg-0-select-leg-checkbox-label"></label>
# </div>
# </div>
# </div>
# <div class="section carrier">
# <img alt="Emirates logo" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EK.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=eef165b19393d24088a2012aa614ecc0aeac8ca6"/>
# </div>
# <div class="section times">
# <div class="top">
# <span class="time-pair"> <span class="depart-time base-time">10:25 </span>
# <span class="time-meridiem meridiem">am</span>
# </span>
# <span class="sep">—</span>
# <span class="time-pair">
# <span class="arrival-time base-time">3:00 </span>
# <span class="time-meridiem meridiem">am</span>
# <span class="adendum" title="Flight lands 2 days later">+2</span>
# </span>
# </div>
# <div class="bottom">Emirates</div> </div>
# <div class="section stops">
# <div class="top">
# 1 stop </div>
# <div class="bottom">
# <span class="js-layover" title="14h 50m layover, &lt;b&gt;Dubai International &amp; other airports&lt;/b&gt;">DXB</span> </div>
# </div>
# <div class="section duration">
# <div class="top">30h 05m</div>
# <div class="bottom">
# <span>IAD</span>
# <span class="sep">&amp;dash;</span>
# <span>AMD</span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="flight ">
# <div class="Flights-Results-LegInfo Flights-Results-LegInfoSleek no-carry-on-column" id="vSsq-info-leg-1">
# <div class="container">
# <div class="section select-leg" id="vSsq-info-leg-1-select-leg-column">
# <div class="select-leg-checkbox" id="vSsq-info-leg-1-select-leg-wrapper">
# <div class="StyleJamCheckbox _bd">
# <input aria-checked="false" aria-disabled="false" aria-label="Show results with this flight only" class="_b _iB _Ir _dc" data-switch-info='{"presentation":"MUTED"}' id="vSsq-info-leg-1-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="_bd _L _M _m _N _kM _R5 _bg _ej _e _bj _br3 _bm _bp _br0 _7D _dT _br1 _ds _br2 _bv _bU _ga _PM _bgV _bsh _bsi _x2" id="vSsq-info-leg-1-select-leg-checkbox-icon"></div>
# <label class="_bd _a _Sw _Sx _e _b1 _Sv _z4 _bsj _br4" data-name="specleg" for="vSsq-info-leg-1-select-leg-checkbox" id="vSsq-info-leg-1-select-leg-checkbox-label"></label>
# </div>
# </div>
# </div>
# <div class="section carrier">
# <img alt="Emirates logo" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EK.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=eef165b19393d24088a2012aa614ecc0aeac8ca6"/>
# </div>
# <div class="section times">
# <div class="top">
# <span class="time-pair"> <span class="depart-time base-time">9:35 </span>
# <span class="time-meridiem meridiem">am</span>
# </span>
# <span class="sep">—</span>
# <span class="time-pair">
# <span class="arrival-time base-time">8:10 </span>
# <span class="time-meridiem meridiem">am</span>
# <span class="adendum" title="Flight lands the next day">+1</span>
# </span>
# </div>
# <div class="bottom">Emirates</div> </div>
# <div class="section stops">
# <div class="top">
# 1 stop </div>
# <div class="bottom">
# <span class="js-layover" title="15h 10m layover, &lt;b&gt;Dubai International &amp; other airports&lt;/b&gt;">DXB</span> </div>
# </div>
# <div class="section duration">
# <div class="top">33h 05m</div>
# <div class="bottom">
# <span>AMD</span>
# <span class="sep">&amp;dash;</span>
# <span>IAD</span>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ol>
# </div>
# </div>
# <div class="Flights-Results-ExtraFlightInfo sleek" id="vSsq-extra-info">
# <div class="section hbo">
# <div class="Flights-Results-PromotedBookingLink right" id="vSsq-extra-info-hbo">
# <div class="book-direct flightPlusGenericXsell hbo-icon hbo-flights inner-link">
# <a class="book-direct-text" href="https://www.kayak.com/s/clickthrough.jsp?ctyp=HighlightedBookingOption&amp;ptyp=F&amp;orig=F..RP..M1&amp;plid=9930856&amp;pid=EmiratesGlobalUS_FHBOAD_US&amp;prv=EmiratesGlobalUS_FHBOAD_US&amp;srch=EqACLXCXSy&amp;ploc=US&amp;atype=HBO&amp;cpnid=7040981&amp;xpExt=&amp;aidExt=&amp;lid=EmiratesGlobalUS_FHBOAD_US-EqACLXCXSy&amp;qorig=Airport:WAS&amp;octid=&amp;qdest=Airport:AMD&amp;qstart=1545282000000&amp;qend=1548565200000&amp;qtravelers=1&amp;qrooms=0&amp;qow=false&amp;qfcc=e&amp;qdctid=29732&amp;qdac=AMD&amp;qshour=-1&amp;qehour=-1&amp;qns=false&amp;qnearby=0&amp;qnearbyo=false&amp;qnearbyd=false&amp;pj=QhCj0$QHZMAswsTlPCwyZg==&amp;ah=mXYUJMG3YIpe0D_WDjPjigniOXIddJ_OPZ2sjHszNgI&amp;resid=a4ecca86d86a60e918a2f573a586eb20&amp;bookid=E-14f1d635ea8&amp;seekProv=EK&amp;trueProv=AMADEUSMASTER&amp;fid=&amp;rank=9" target="_blank">
# $2502 directly with Emirates </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-price result-column" id="vSsq-priceSection">
# <div class="Flights-Results-FlightPriceSection right-alignment sleek" id="vSsq-price">
# <div class="top-row">
# <div class="left-column">
# <div class="Flights-Results-FlightFeeIcons _v" id="vSsq-price-flight-fee-icons">
# <div class="_0T _A _0V _N3 _0X _0Z _bZW _bZX _dT _bZY _bZZ _bU _bZ0 _bZ1 _kM _Km _FP _ds _fx _fw _s _Av _ga _x _kh _bZ3" id="vSsq-price-flight-fee-icons-carryOnBags">
# <div class="_k _O _QB _bfv">
# <svg class="" fill="currentColor" height="10" viewbox="0 0 9 10" width="9" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-carry-on-bag"></use></svg> </div>
# <div class="_k _o _QB _bcW">
# 1
# </div>
# </div>
# <div class="_0T _A _0V _N3 _0X _0Z _bZW _bZX _dT _bZY _bZZ _bU _bZ0 _bZ1 _kM _Km _FP _ds _fx _fw _s _Av _ga _x _kh _bZ3" id="vSsq-price-flight-fee-icons-checkedBags">
# <div class="_k _O _QB _mi">
# <svg class="_z" fill="currentColor" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#flights-results-checked-bag_z"></use></svg> </div>
# <div class="_k _o _QB _bcW">
# 2
# </div>
# </div>
# </div>
# </div>
# <div class="Common-Results-ResultOptionsMenu Theme-grey _uN _eQ _g2 _bg5" id="NGje">
# <button aria-label="More options" class="_a _A _r _s _v _z _wD Button-No-Standard-Style" id="NGje-menu-trigger" title="More options">
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# <span class="_kM _e _xV _xU _vS _xX _m _xW _N"></span>
# </button>
# <div class="Common-Widgets-Tip-ToolTip" id="NGje-menu-trigger-rendered-content">
# <div class="_A _q _v _fR _Gr _r0 _c1 _c2 _n">
# <div class="_r _gL _v _g2">
# <div class="Common-Trips-ResultItemSaveToTrips row-item grey" id="NGje-save">
# <a aria-label="Watch flight" aria-pressed="false" class="layer-content watchlist-style" href="javascript:void(0)" id="NGje-save-save" role="button">
# <div class="icon icon-filled">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 0H5C3.896 0 3 .895 3 2v22l9-8 9 8V2c0-1.105-.896-2-2-2zm-7.757 12L7 7.757l1.414-1.414 2.828 2.828 4.95-4.95 1.414 1.415L11.243 12z"></path></svg> </div>
# <div class="icon icon-outline">
# <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 2v17.546l-7-6.222-7 6.222V2h14m0-2H5C3.896 0 3 .895 3 2v22l9-8 9 8V2c0-1.105-.896-2-2-2z"></path></svg> </div>
# <span class="title saveLinkText" id="NGje-save-title">
# Watch flight
# </span>
# </a>
# </div>
# </div>
# <div class="_r _gL _v _g2 _bp _bo _dT">
# <a aria-haspopup="true" aria-label="Share" class="Common-Results-ShareLink Icon-default row-item grey" href="javascript:void(0)" id="NGje-share" role="button">
# <div class="shareIcon" id="NGje-share-icon">
# <svg height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g transform="translate(.49 .49)"><ellipse cx="13.935" cy="3.036" rx="3.065" ry="3.036"></ellipse><ellipse cx="3.065" cy="9.107" rx="3.065" ry="3.036"></ellipse><ellipse cx="13.935" cy="13.964" rx="3.065" ry="3.036"></ellipse><path d="M4.94 6.987l6.567-3.492.749 1.408-6.568 3.492zM5.312 10.97l6.568 3.492.748-1.408L6.06 9.562z"></path></g></svg> </div>
# <div class="shareLabel" id="NGje-share-label">
# Share
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="booking" id="vSsq-price-bookingSection">
# <div class="multibook-dropdown">
# <div class="Common-Booking-VerticalMultiBookDropdown Common-Booking-CategorizedVerticalMultiBookDropdown align-right with-dropdown" id="vSsq-price-mb">
# <div class="above-button" id="vSsq-price-mb-above-button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider whisky-provider featured-provider multi-row Theme-featured-large" id="vSsq-price-mb-aE-10b493d523f">
# <a aria-label="$2077 from KAYAK" class="booking-link" href="/book/flight?code=EqACLXCXSy.Phr0MPX3rp0mFcdAejOqIg.207628.a4ecca86d86a60e918a2f573a586eb20&amp;h=16e6767f8eea&amp;_kw_pbranded=true&amp;sub=E-10b493d523f" id="vSsq-price-mb-aE-10b493d523f-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2077 </span>
# <span class="providerName option-text">
# KAYAK
# </span>
# </a>
# </div>
# </div>
# <div class="above-button">
# <div class="Flights-Booking-FareFamilyOptionsList Flights-Booking-FareFamilyWarning sleek Theme-right sleek" id="vSsq-price-ff-warning">
# <div class="details-container dialog-trigger-with-text links">
# <span class="tip dialog-trigger-with-text" id="vSsq-price-ff-warning-toolTipTarget">
# <span class="label">Saver </span>
# </span>
# </div>
# </div>
# </div>
# <div class="keel-grid multibookGrid" id="vSsq-price-mb-dropdown-grid" role="listbox">
# <div class="col col-best ">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-m bookingButton whisky-provider" id="vSsq-price-mb-best" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small whisky-provider featured-provider " id="vSsq-price-mb-bE-10b493d523f">
# <a aria-label="View Deal" class="booking-link" href="/book/flight?code=EqACLXCXSy.Phr0MPX3rp0mFcdAejOqIg.207628.a4ecca86d86a60e918a2f573a586eb20&amp;h=16e6767f8eea&amp;_kw_pbranded=true&amp;sub=E-10b493d523f" id="vSsq-price-mb-bE-10b493d523f-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# View Deal
# </span>
# </a>
# </div>
# </div>
# </div>
# <div class="col-dropdown whisky-provider">
# <a aria-controls="vSsq-price-mb-dropdown_content" aria-expanded="false" aria-haspopup="true" aria-label="" aria-owns="vSsq-price-mb-dropdown_content" aria-pressed="false" class="Common-Widgets-Dropdown-DropdownDialog ui-button Button-Gradient-End multibook size-m iconOnly" data-alignment="right" data-expandto="vSsq-price-mb-dropdown-grid" href="javascript:void(0)" id="vSsq-price-mb-dropdown" role="button">
# <div class="label">
# </div>
# <div class="placeholder">
# </div>
# <div class="icon">
# <svg class="" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.35" viewbox="0 0 8 5" xmlns="http://www.w3.org/2000/svg"><path d="M7 1.053L4.027 4 1 1" fill="none" stroke="currentColor"></path></svg> </div>
# </a>
# <div aria-expanded="false" class="Common-Widgets-Dropdown-DropdownDialog-Content Common-Booking-VerticalMultiBookDropdown-Content slide-down-animation Common-Booking-CategorizedVerticalMultiBookDropdownList-Content R9-Overlay animate-top-right" data-dropdown-owner="vSsq-price-mb" id="vSsq-price-mb-dropdown_content" role="dialog">
# <div class="animation-container">
# <ul class="option-list" id="vSsq-price-mb-list">
# <div class="Common-Booking-CategorizedVerticalMultiBookDropdownList" id="vSsq-price-mb-dd">
# <div class="option-categories">
# <div class="category-label category-whisky">Book on KAYAK</div>
# <ul aria-label="Book on KAYAK" class="option-list whisky-list">
# <li>
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-dropdown-item whisky-provider featured-provider " id="vSsq-price-mb-dd-E-10b493d523f">
# <a aria-label="$2077 from KAYAK" class="booking-link" href="/book/flight?code=EqACLXCXSy.Phr0MPX3rp0mFcdAejOqIg.207628.a4ecca86d86a60e918a2f573a586eb20&amp;h=16e6767f8eea&amp;_kw_pbranded=true&amp;sub=E-10b493d523f" id="vSsq-price-mb-dd-E-10b493d523f-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2077 </span>
# <span class="providerName option-text">
# KAYAK
# </span>
# </a>
# </div>
# </li>
# </ul>
# <div class="category-label category-external">More Booking Options</div>
# <ul aria-label="More Booking Options" class="option-list external-list">
# <li>
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-dropdown-item" id="vSsq-price-mb-dd-E-13d890573b4">
# <a aria-label="$2117 from Indian Eagle" class="booking-link" href="/book/flight?code=EqACLXCXSy.T902IqN2TowOb7AKMWXkpw.211623.a4ecca86d86a60e918a2f573a586eb20&amp;h=e2231bb7beb0&amp;sub=E-13d890573b4" id="vSsq-price-mb-dd-E-13d890573b4-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2117 </span>
# <span class="providerName option-text">
# Indian Eagle
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-dropdown-item" id="vSsq-price-mb-dd-E-13bd5b84f8c">
# <a aria-label="$2127 from Priceline" class="booking-link" href="/book/flight?code=EqACLXCXSy.JZO1f6NT9B8-ciubBqDvug.212623.a4ecca86d86a60e918a2f573a586eb20&amp;h=912718c79796&amp;sub=E-13bd5b84f8c" id="vSsq-price-mb-dd-E-13bd5b84f8c-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2127 </span>
# <span class="providerName option-text">
# Priceline
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-dropdown-item" id="vSsq-price-mb-dd-E-189937d886e">
# <a aria-label="$2127 from FlightNetwork" class="booking-link" href="/book/flight?code=EqACLXCXSy.lPAzY077B9kUPBPf-jqMFw.212623.a4ecca86d86a60e918a2f573a586eb20&amp;h=ed75529e51dd&amp;sub=E-189937d886e" id="vSsq-price-mb-dd-E-189937d886e-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2127 </span>
# <span class="providerName option-text">
# FlightNetwork
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="Common-Booking-MultiBookProvider Theme-dropdown-item overflow-provider" id="vSsq-price-mb-dd-E-1e5320a161c">
# <a aria-label="$2127 from CheapOair" class="booking-link" href="/book/flight?code=EqACLXCXSy.B804y7I_OvzTYwQ_VUUUMA.212614.a4ecca86d86a60e918a2f573a586eb20&amp;h=1291cec1b152&amp;sub=E-1e5320a161c" id="vSsq-price-mb-dd-E-1e5320a161c-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2127 </span>
# <span class="providerName option-text">
# CheapOair
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="Common-Booking-MultiBookProvider Theme-dropdown-item overflow-provider" id="vSsq-price-mb-dd-E-17d932e7e7f">
# <a aria-label="$2127 from OneTravel" class="booking-link" href="/book/flight?code=EqACLXCXSy.ZGCjmBy1GCgLB6vGR1cxFw.212614.a4ecca86d86a60e918a2f573a586eb20&amp;h=1995e8a10bef&amp;sub=E-17d932e7e7f" id="vSsq-price-mb-dd-E-17d932e7e7f-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2127 </span>
# <span class="providerName option-text">
# OneTravel
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="Common-Booking-MultiBookProvider Theme-dropdown-item overflow-provider" id="vSsq-price-mb-dd-E-1af2408bd31">
# <a aria-label="$2466 from Vayama" class="booking-link" href="/book/flight?code=EqACLXCXSy.vZik3Z2arcoEdn9PX-8xhQ.246558.a4ecca86d86a60e918a2f573a586eb20&amp;h=c97b6a162809&amp;sub=E-1af2408bd31" id="vSsq-price-mb-dd-E-1af2408bd31-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2466 </span>
# <span class="providerName option-text">
# Vayama
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="Common-Booking-MultiBookProvider Theme-dropdown-item overflow-provider" id="vSsq-price-mb-dd-E-14bb5181101">
# <a aria-label="$2502 from Orbitz" class="booking-link" href="/book/flight?code=EqACLXCXSy.8ieUdrMIIwWV5sM362aTbQ.250114.a4ecca86d86a60e918a2f573a586eb20&amp;h=b07cd82f2e9e&amp;sub=E-14bb5181101" id="vSsq-price-mb-dd-E-14bb5181101-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2502 </span>
# <span class="providerName option-text">
# Orbitz
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="Common-Booking-MultiBookProvider expensive Theme-dropdown-item overflow-provider" id="vSsq-price-mb-dd-E-14f1d635ea8">
# <a aria-label="$2502 from Emirates" class="booking-link" href="/book/flight?code=EqACLXCXSy.jxdaUIMsDidFj024N3_sTg.250114.a4ecca86d86a60e918a2f573a586eb20&amp;h=e67d2641c969&amp;sub=E-14f1d635ea8" id="vSsq-price-mb-dd-E-14f1d635ea8-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# $2502 </span>
# <span class="providerName option-text">
# Emirates
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="Common-Booking-MultiBookProvider Theme-dropdown-item overflow-provider cheapest " id="vSsq-price-mb-dd-E-122de5183af">
# <a aria-label="check rates from Expedia" class="booking-link" href="/book/flight?code=EqACLXCXSy.zGg9D0gRJwDTdP4J7zpVtg.-100.a4ecca86d86a60e918a2f573a586eb20&amp;h=4a011b71d65e&amp;sub=E-122de5183af" id="vSsq-price-mb-dd-E-122de5183af-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# <svg viewbox="0 0 28 28" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-booking-magnifying-glass"></use></svg> </span>
# <span class="providerName option-text">
# Expedia
# </span>
# </a>
# </div>
# </li>
# <li>
# <div aria-hidden="true" class="Common-Booking-MultiBookProvider Theme-dropdown-item overflow-provider" id="vSsq-price-mb-dd-E-1ad2ac2181f">
# <a aria-label="check rates from Travelocity" class="booking-link" href="/book/flight?code=EqACLXCXSy.7CBQf_BXsHos-H8mLHGm3oYDM8dquPAK.-100.a4ecca86d86a60e918a2f573a586eb20&amp;h=ffdbf11d9580&amp;sub=E-1ad2ac2181f" id="vSsq-price-mb-dd-E-1ad2ac2181f-booking-link" role="option" tabindex="0" target="_blank">
# <span class="price option-text">
# <svg viewbox="0 0 28 28" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-booking-magnifying-glass"></use></svg> </span>
# <span class="providerName option-text">
# Travelocity
# </span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </ul>
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Grey ui-button size-c overflow-button Theme-dropdown-item--overflow" id="vSsq-price-mb-overflow" role="button" type="button">
# 7 more from $2127
# <svg class="common-widgets-chevron overflow-chevron" viewbox="0 0 10 10" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-icon-chevronoverflow-chevron"></use></svg>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="fare-family">
# <div class="Flights-Booking-FareFamilyOptionsList wide-display sleek" id="vSsq-price-ff">
# <div class="links" id="vSsq-price-ff-links">
# <div class="fare-option" id="vSsq-price-ff-link-0">
# <a aria-label="Flex for $2502" class="fare-booking-link " data-airline="EK" data-code="ECOFLEX" data-href="/book/flight?code=EqACLXCXSy.8ieUdrMIIwWV5sM362aTbQ.250114.a4ecca86d86a60e918a2f573a586eb20&amp;h=b07cd82f2e9e&amp;sub=E-14bb5181101" data-price="$2502" data-providercode="ORBITZAIRINTLSYN" data-providername="Orbitz" data-tglairline="Emirates" data-tglcabin="e" data-tglcurrency="USD" data-tgllegs="2" data-tglprice="2502.0" href="/book/flight?code=EqACLXCXSy.8ieUdrMIIwWV5sM362aTbQ.250114.a4ecca86d86a60e918a2f573a586eb20&amp;h=b07cd82f2e9e&amp;sub=E-14bb5181101" tabindex="0" target="_blank">
# <div class="flex-icon-spacer">
# </div>
# <div class="fare-family-price">
# $2502
# </div>
# <div class="fare-family-name">
# Flex
# </div>
# </a>
# </div>
# <div class="fare-option" id="vSsq-price-ff-link-1">
# <a aria-label="Flex Plus for $3117" class="fare-booking-link " data-airline="EK" data-code="ECOFLXPLUS" data-href="/book/flight?code=EqACLXCXSy.jxdaUIMsDidFj024N3_sTg.311614.a4ecca86d86a60e918a2f573a586eb20&amp;h=acd58ce6504b&amp;sub=E-16833b64a1f" data-price="$3117" data-providercode="EK" data-providername="Emirates" data-tglairline="Emirates" data-tglcabin="e" data-tglcurrency="USD" data-tgllegs="2" data-tglprice="3117.0" href="/book/flight?code=EqACLXCXSy.jxdaUIMsDidFj024N3_sTg.311614.a4ecca86d86a60e918a2f573a586eb20&amp;h=acd58ce6504b&amp;sub=E-16833b64a1f" tabindex="0" target="_blank">
# <div class="flex-icon-spacer">
# </div>
# <div class="fare-family-price">
# $3117
# </div>
# <div class="fare-family-name">
# Flex Plus
# </div>
# </a>
# </div>
# <div class="Common-Widgets-Tip-ToolTip" id="vSsq-price-ff-links-rendered-content">
# <div class="Flights-Booking-FareFamilyComparisonPanel" id="RkoP">
# <div class="flex-container" id="RkoP-column-container">
# <div class="option-column js-option-column ECOSAVER" data-airline="EK" data-code="ECOSAVER" data-price="$2077">
# <div class="option-column-info">
# <div aria-label="Saver for $2077" class="heading">
# <span class="heading-price">$2077</span>
# <span class="heading-name">Saver</span>
# </div>
# <div class="details">
# <ul class="detail-list inner-content">
# <li aria-label="Includes: Meal &amp; beverages" class="detail incl">
# <span class="detail-icon">
# <svg class="" viewbox="0 0 26 26" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-icon-checkmark"></use></svg> </span>
# <span class="detail-description">
# Meal &amp; beverages </span>
# </li>
# <li aria-label="Includes: 35 percent miles earned" class="detail incl">
# <span class="detail-icon">
# <svg class="" viewbox="0 0 26 26" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-icon-checkmark"></use></svg> </span>
# <span class="detail-description">
# 35 percent miles earned </span>
# </li>
# <li aria-label="Available for purchase: Pre-reserved seat assignment" class="detail fee">
# <span class="detail-icon">
# $ </span>
# <span class="detail-description">
# Pre-reserved seat assignment </span>
# </li>
# <li aria-label="Available for purchase: Upgrade eligibility" class="detail fee">
# <span class="detail-icon">
# $ </span>
# <span class="detail-description">
# Upgrade eligibility </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="option-column js-option-column ECOFLEX" data-airline="EK" data-code="ECOFLEX" data-price="$2502">
# <div class="option-column-info">
# <div aria-label="Flex for $2502" class="heading">
# <span class="heading-price">$2502</span>
# <span class="heading-name">Flex</span>
# </div>
# <div class="details">
# <ul class="detail-list inner-content">
# <li aria-label="Includes: Meal &amp; beverages" class="detail incl">
# <span class="detail-icon">
# <svg class="" viewbox="0 0 26 26" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-icon-checkmark"></use></svg> </span>
# <span class="detail-description">
# Meal &amp; beverages </span>
# </li>
# <li aria-label="Includes: 70 percent miles earned" class="detail incl">
# <span class="detail-icon">
# <svg class="" viewbox="0 0 26 26" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-icon-checkmark"></use></svg> </span>
# <span class="detail-description">
# 70 percent miles earned </span>
# </li>
# <li aria-label="Available for purchase: Pre-reserved seat assignment" class="detail fee">
# <span class="detail-icon">
# $ </span>
# <span class="detail-description">
# Pre-reserved seat assignment </span>
# </li>
# <li aria-label="Available for purchase: Upgrade eligibility" class="detail fee">
# <span class="detail-icon">
# $ </span>
# <span class="detail-description">
# Upgrade eligibility </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="option-column js-option-column ECOFLXPLUS" data-airline="EK" data-code="ECOFLXPLUS" data-price="$3117">
# <div class="option-column-info">
# <div aria-label="Flex Plus for $3117" class="heading">
# <span class="heading-price">$3117</span>
# <span class="heading-name">Flex Plus</span>
# </div>
# <div class="details">
# <ul class="detail-list inner-content">
# <li aria-label="Includes: Meal &amp; beverages" class="detail incl">
# <span class="detail-icon">
# <svg class="" viewbox="0 0 26 26" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-icon-checkmark"></use></svg> </span>
# <span class="detail-description">
# Meal &amp; beverages </span>
# </li>
# <li aria-label="Includes: 100 percent miles earned" class="detail incl">
# <span class="detail-icon">
# <svg class="" viewbox="0 0 26 26" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#common-icon-checkmark"></use></svg> </span>
# <span class="detail-description">
# 100 percent miles earned </span>
# </li>
# <li aria-label="Available for purchase: Pre-reserved seat assignment" class="detail fee">
# <span class="detail-icon">
# $ </span>
# <span class="detail-description">
# Pre-reserved seat assignment </span>
# </li>
# <li aria-label="Available for purchase: Upgrade eligibility" class="detail fee">
# <span class="detail-icon">
# $ </span>
# <span class="detail-description">
# Upgrade eligibility </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="detailsWrapper" id="vSsq-detailsWrapper">
# <div class="detailsContent detailsContainer" id="vSsq-detailsContent">
# <div class="Flights-Results-FlightResultDetails Flights-Results-FlightResultDetailsV3 tab-refresh" id="vSsq-details">
# <section aria-expanded="true" class="details-section overviewSection" data-tab="overview" id="vSsq-details-leg-details" role="tabpanel">
# <div class="section-content">
# <div class="Flights-Results-FlightLegDetails" id="u59I">
# <div class="header">
# <div class="spec-leg left">
# <span class="leg-filter-checkbox">
# <span class="checkbox-wrapper" id="u59I-select-leg-wrapper">
# <div class="Common-Widgets-Checkbox-Checkbox select-leg-checkbox disable-mouseout-animation size-m ">
# <input aria-checked="false" aria-disabled="false" aria-labelledby="u59I-select-leg-checkbox-label" id="u59I-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="icon" id="u59I-select-leg-checkbox-icon"></div>
# <label class="label" data-name="specleg" for="u59I-select-leg-checkbox" id="u59I-select-leg-checkbox-label">Depart</label>
# </div>
# </span>
# </span>
# </div>
# <div class="airports left">
# <span class="origin-destination">
# IAD - AMD
# </span>
# </div>
# <div class="times right">
# <span class="duration">30h 05m</span>
# </div>
# </div>
# <div class="content-card">
# <div class="segment-row" data-flightnumber="232">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Thu, Dec 20
# </div>
# <div class="arrival-date-warning">
# Lands Fri, Dec 21 </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Emirates" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EK.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=eef165b19393d24088a2012aa614ecc0aeac8ca6"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">10:25 am</span>
# —
# <span class="time">8:10 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Washington</span>
# </span>
# -
# <span class="destination">
# <span class="city">Dubai</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 12h 45m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="yjoM">
# <div class="keel-grid iconGrid" id="yjoM-icons">
# <div class="col-icon">
# <div class="item code-w"></div>
# </div>
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Emirates 232 · Wide-body jet · Airbus A380-800 </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="w09I" tabindex="0">
# <div class="keel-grid layoverGrid warn">
# <div class="col-10-12">
# <div class="layoverText " id="w09I-layover-text">
# Change planes in Dubai (DXB)
# </div>
# <div class="layoverWarning ">
# Long layover </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">14h 49m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="538">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Fri, Dec 21
# </div>
# <div class="arrival-date-warning">
# Lands Sat, Dec 22 </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid last" tabindex="0">
# <div class="icon-column">
# <img alt="Emirates" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EK.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=eef165b19393d24088a2012aa614ecc0aeac8ca6"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">11:00 pm</span>
# —
# <span class="time">3:00 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Dubai</span>
# </span>
# -
# <span class="destination">
# <span class="city">Ahmedabad</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 2h 30m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="cEkF">
# <div class="keel-grid iconGrid" id="cEkF-icons">
# <div class="col-icon">
# <div class="item code-w"></div>
# </div>
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Emirates 538 · Wide-body jet · Boeing 777-200LR </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-content">
# <div class="Flights-Results-FlightLegDetails" id="c1Qba">
# <div class="header">
# <div class="spec-leg left">
# <span class="leg-filter-checkbox">
# <span class="checkbox-wrapper" id="c1Qba-select-leg-wrapper">
# <div class="Common-Widgets-Checkbox-Checkbox select-leg-checkbox disable-mouseout-animation size-m ">
# <input aria-checked="false" aria-disabled="false" aria-labelledby="c1Qba-select-leg-checkbox-label" id="c1Qba-select-leg-checkbox" name="specleg" type="checkbox" value=""/>
# <div class="icon" id="c1Qba-select-leg-checkbox-icon"></div>
# <label class="label" data-name="specleg" for="c1Qba-select-leg-checkbox" id="c1Qba-select-leg-checkbox-label">Return</label>
# </div>
# </span>
# </span>
# </div>
# <div class="airports left">
# <span class="origin-destination">
# AMD - IAD
# </span>
# </div>
# <div class="times right">
# <span class="duration">33h 05m</span>
# </div>
# </div>
# <div class="content-card">
# <div class="segment-row" data-flightnumber="541">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Sun, Jan 27
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid" tabindex="0">
# <div class="icon-column">
# <img alt="Emirates" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EK.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=eef165b19393d24088a2012aa614ecc0aeac8ca6"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">9:35 am</span>
# —
# <span class="time">11:15 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Ahmedabad</span>
# </span>
# -
# <span class="destination">
# <span class="city">Dubai</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 3h 10m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="nsRl">
# <div class="keel-grid iconGrid" id="nsRl-icons">
# <div class="col-icon">
# <div class="item code-w"></div>
# </div>
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Emirates 541 · Wide-body jet · Boeing 777-200LR </div>
# </div>
# </div>
# </div>
# <div class="segment-details-grid modal-min-hide">
# <div class="layover-container">
# <div class="Flights-Results-FlightLayoverDetails" id="c1MrT" tabindex="0">
# <div class="keel-grid layoverGrid warn">
# <div class="col-10-12">
# <div class="layoverText " id="c1MrT-layover-text">
# Change planes in Dubai (DXB)
# </div>
# <div class="layoverWarning ">
# Long layover </div>
# </div>
# <div class="col-2-12 right">
# <div class="layoverDuration">15h 09m</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="segment-row" data-flightnumber="231">
# <div class="left-column segment-dates">
# <div class="leg-dates-set">
# <div class="date">
# Mon, Jan 28
# </div>
# </div>
# </div>
# <div class="right-column segment-details">
# <div class="segment-details-grid last" tabindex="0">
# <div class="icon-column">
# <img alt="Emirates" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/v/EK.png?crop=false&amp;width=108&amp;height=92&amp;fallback=default1.png&amp;_v=eef165b19393d24088a2012aa614ecc0aeac8ca6"/>
# </div>
# <div class="keel-grid legGrid">
# <div class="col-7-12 col-segment-heading">
# <div class="segmentTimes details-heading text-row">
# <span class="time">2:25 am</span>
# —
# <span class="time">8:10 am</span>
# </div>
# <div class="airport-codes details-heading text-row">
# <span class="origin">
# <span class="city">Dubai</span>
# </span>
# -
# <span class="destination">
# <span class="city">Washington</span>
# </span>
# </div>
# </div>
# <div class="col-5-12 col-segment-aside cabin-duration details-heading right modal-min-hide">
# <div class="text-row">
# <span class="segmentCabinClass">
# Economy
# </span>
# <span class="segmentDuration text-row">
# 14h 45m
# </span>
# </div>
# <div class="qualityIcons text-row">
# <div aria-label="Quality icons" class="Flights-Results-QualityIcons" id="eeU1">
# <div class="keel-grid iconGrid" id="eeU1-icons">
# <div class="col-icon">
# <div class="item code-w"></div>
# </div>
# <div class="col-icon">
# <div class="item code-ent"></div>
# </div>
# <div class="col-icon">
# <div class="item code-pwr"></div>
# </div>
# <div class="col-icon">
# <div class="item code-seat"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col text-row modal-min-hide">
# <div class="planeDetails details-subheading">
# Emirates 231 · Wide-body jet · Airbus A380-800 </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section aria-expanded="true" class="details-section bookingSection" data-tab="rates" id="vSsq-details-rates" role="tabpanel">
# <div class="Flights-Results-FlightRatesTable Flights-Results-FlightRatesTableV3 carry-on-design" id="c6cVw">
# <header class="main-header">
# <h3 class="title left">
# Booking Options </h3>
# </header>
# <div class="category-selection">
# <span class="Common-Widgets-Radio-RadioButtonSet label-grey size-l Button-round" id="c6cVw-category-radios">
# <span id="c6cVw-category-radios-set" role="tablist" tabindex="0">
# <input aria-checked="true" aria-controls="c6cVw-ECOSAVER" aria-labelledby="c6cVw-fare-button-ECOSAVER-label" checked="true" class="r9-radiobuttonset hidden" id="c6cVw-fare-button-ECOSAVER" name="c6cVw-rates-table-category" type="tab" value="ECOSAVER"/>
# <label class="r9-radiobuttonset-label r9-radiobuttonset-label-checked" for="c6cVw-fare-button-ECOSAVER" id="c6cVw-fare-button-ECOSAVER-label" title="">
# <span class="r9-radiobuttonset-circle circle-color-grey hidden" id="c6cVw-fare-button-ECOSAVER-button"></span>
# <span class="label-text">Saver</span>
# </label>
# <input aria-checked="false" aria-controls="c6cVw-ECOFLEX" aria-labelledby="c6cVw-fare-button-ECOFLEX-label" class="r9-radiobuttonset hidden" id="c6cVw-fare-button-ECOFLEX" name="c6cVw-rates-table-category" type="tab" value="ECOFLEX"/>
# <label class="r9-radiobuttonset-label " for="c6cVw-fare-button-ECOFLEX" id="c6cVw-fare-button-ECOFLEX-label" title="">
# <span class="r9-radiobuttonset-circle circle-color-grey hidden" id="c6cVw-fare-button-ECOFLEX-button"></span>
# <span class="label-text">Flex</span>
# </label>
# <input aria-checked="false" aria-controls="c6cVw-ECOFLXPLUS" aria-labelledby="c6cVw-fare-button-ECOFLXPLUS-label" class="r9-radiobuttonset hidden" id="c6cVw-fare-button-ECOFLXPLUS" name="c6cVw-rates-table-category" type="tab" value="ECOFLXPLUS"/>
# <label class="r9-radiobuttonset-label " for="c6cVw-fare-button-ECOFLXPLUS" id="c6cVw-fare-button-ECOFLXPLUS-label" title="">
# <span class="r9-radiobuttonset-circle circle-color-grey hidden" id="c6cVw-fare-button-ECOFLXPLUS-button"></span>
# <span class="label-text">Flex Plus</span>
# </label>
# <input aria-checked="false" aria-controls="c6cVw-b" aria-labelledby="c6cVw-fare-button-b-label" class="r9-radiobuttonset hidden" id="c6cVw-fare-button-b" name="c6cVw-rates-table-category" type="tab" value="b"/>
# <label class="r9-radiobuttonset-label " for="c6cVw-fare-button-b" id="c6cVw-fare-button-b-label" title="">
# <span class="r9-radiobuttonset-circle circle-color-grey hidden" id="c6cVw-fare-button-b-button"></span>
# <span class="label-text">Business</span>
# </label>
# <input aria-checked="false" aria-controls="c6cVw-BSSAVER" aria-labelledby="c6cVw-fare-button-BSSAVER-label" class="r9-radiobuttonset hidden" id="c6cVw-fare-button-BSSAVER" name="c6cVw-rates-table-category" type="tab" value="BSSAVER"/>
# <label class="r9-radiobuttonset-label " for="c6cVw-fare-button-BSSAVER" id="c6cVw-fare-button-BSSAVER-label" title="">
# <span class="r9-radiobuttonset-circle circle-color-grey hidden" id="c6cVw-fare-button-BSSAVER-button"></span>
# <span class="label-text">Saver</span>
# </label>
# <input aria-checked="false" aria-controls="c6cVw-" aria-labelledby="c6cVw-fare-button--label" class="r9-radiobuttonset hidden" id="c6cVw-fare-button-" name="c6cVw-rates-table-category" type="tab" value=""/>
# <label class="r9-radiobuttonset-label " for="c6cVw-fare-button-" id="c6cVw-fare-button--label" title="">
# <span class="r9-radiobuttonset-circle circle-color-grey hidden" id="c6cVw-fare-button--button"></span>
# <span class="label-text">Mixed</span>
# </label>
# </span>
# ...
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="lm3G" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="c5Epc" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="gT3f-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small" id="jsHS">
# <a aria-label="$2278" class="booking-link" href="/book/flight?code=EqACLXCXSy.-tVKCyXL02txUWQk5ndetA.227723.3a7c97e289db6b4993193512e17fbfc3&amp;h=ab07291ab159&amp;sub=E-16f4cb139e8" id="jsHS-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $2278
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-4" id="FuM9" role="row">
# <div class="cell logo end-left-alignment " role="gridcell">
# <img alt="KAYAK" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/h/kayak-logo.png?crop=false&amp;width=88&amp;height=31&amp;fallback=default2.png&amp;_v=a0d5bc4351ca838340f6f620d50049eb738666a1" title="KAYAK"/>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="anll" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="DAHi" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="FuM9-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small whisky-provider " id="GKM7">
# <a aria-label="$2333" class="booking-link" href="/book/flight?code=EqACLXCXSy.y-wK1suL8fUCnA0yuAeUaw.233228.3a7c97e289db6b4993193512e17fbfc3&amp;h=1d69b1eb4d60&amp;_kw_pbranded=true&amp;sub=E-15d9299e96f" id="GKM7-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $2333
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-5" id="ukmn" role="row">
# <div class="cell logo end-left-alignment " role="gridcell">
# <img alt="CheapTickets.com" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/h/CHEAPTICKETS.png?crop=false&amp;width=88&amp;height=31&amp;fallback=default2.png&amp;_v=2d0cc522c9a9b2cd7bc0cf65e6ab2c324b04af08" title="CheapTickets.com"/>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="qEFJ" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="FVSD" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="ukmn-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small" id="Rk3u">
# <a aria-label="$2333" class="booking-link" href="/book/flight?code=EqACLXCXSy.jrtvZk32l8TiO-uPwnKPlA.233227.3a7c97e289db6b4993193512e17fbfc3&amp;h=68c4844cfac5&amp;sub=E-1d0179b7fd7" id="Rk3u-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $2333
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-6" id="c6tnr" role="row">
# <div class="cell logo end-left-alignment " role="gridcell">
# <img alt="JustFly" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/h/FLIGHTHUB.us.png?crop=false&amp;width=88&amp;height=31&amp;fallback=default1.png&amp;_v=e5c8d947bd8d9bd0bc108bfecbc8fa2e1ab9d565" title="JustFly"/>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="EU8p" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="c2PO0" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="c6tnr-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small" id="mxRt">
# <a aria-label="$2333" class="booking-link" href="/book/flight?code=EqACLXCXSy.2UFg3_Lii-UH7S5X9hxNmw.233228.3a7c97e289db6b4993193512e17fbfc3&amp;h=566bd37cb73b&amp;sub=E-1bf72d4887a" id="mxRt-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $2333
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-7" id="kI-J" role="row">
# <div class="cell logo end-left-alignment " role="gridcell">
# <img alt="FlightHub" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/h/FLIGHTHUBUS.png?crop=false&amp;width=88&amp;height=31&amp;fallback=default3.png&amp;_v=31b3567106170a19e2c3bdd57ff52888227e7119" title="FlightHub"/>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="DFVm" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="hJDg" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="kI-J-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small" id="IX4F">
# <a aria-label="$2333" class="booking-link" href="/book/flight?code=EqACLXCXSy.bdwTMsROOF51xKVWTdlzgw.233228.3a7c97e289db6b4993193512e17fbfc3&amp;h=aec5ce6602fb&amp;sub=E-1c2df882ecd" id="IX4F-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $2333
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-8" id="ZiAa" role="row">
# <div class="cell logo end-left-alignment " role="gridcell">
# <img alt="Vayama" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/h/VAYAMA.png?crop=false&amp;width=88&amp;height=31&amp;fallback=default2.png&amp;_v=a30e77b3d868ccd881ffa621421939f94d62d6f3" title="Vayama"/>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="W_Gd" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="Vzki" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="ZiAa-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small" id="BLzH">
# <a aria-label="$2335" class="booking-link" href="/book/flight?code=EqACLXCXSy.vZik3Z2arcoEdn9PX-8xhQ.233421.3a7c97e289db6b4993193512e17fbfc3&amp;h=7ac097dbb95d&amp;sub=E-1fd6c3a47f4" id="BLzH-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $2335
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-9" id="ZvLK" role="row">
# <div class="cell logo end-left-alignment " role="gridcell">
# <img alt="Priceline" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/h/PRICELINEFLIGHTS.png?crop=false&amp;width=88&amp;height=31&amp;fallback=default3.png&amp;_v=234168ddbea795f9fba73cd5a7ea17d6ada91c89" title="Priceline"/>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="y_Cl" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="vdFc" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="ZvLK-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small" id="JFM1">
# <a aria-label="$3976" class="booking-link" href="/book/flight?code=EqACLXCXSy.j3mok_JebFPepVIzRCVkeLaYAeeTFjgE.397543.3a7c97e289db6b4993193512e17fbfc3&amp;h=2ad71d89b5ef&amp;sub=E-19b4ca78020" id="JFM1-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $3976
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="Flights-Results-FlightRatesTableProvider Flights-Results-FlightRatesTableProviderV2" data-tableid="e-10" id="jMZ6" role="row">
# <div class="cell logo end-left-alignment " role="gridcell">
# <img alt="Orbitz" src="https://a1.r9cdn.net/rimg/provider-logos/airlines/h/ORBITZAIR.png?crop=false&amp;width=88&amp;height=31&amp;fallback=default2.png&amp;_v=cc029bd118b08e8140ee183d95d305de55a01e6e" title="Orbitz"/>
# </div>
# <div class="cell cabin grey-cell" role="gridcell">
# <span class="icon cell-content">
# Economy
# </span>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="XJbf" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell baggage-fees grey-cell" role="gridcell">
# <span class="fee-amount cell-content">
# Included
# </span>
# <div class="Common-Widgets-Loader-Loader loader " id="UWhB" style="height: 14px;line-height:14px">
# <span class="dot dot0" style="width:7px;height:7px;"></span><span class="dot dot1" style="width:7px;height:7px;"></span><span class="dot dot2" style="width:7px;height:7px;"></span>
# </div>
# </div>
# <div class="cell booking-total fixed-cell" role="gridcell">
# <div aria-hidden="false" class="Common-Widgets-Button-ButtonDeprecated Common-Widgets-Button-Button Button-Gradient ui-button size-s " id="jMZ6-booking-button" role="button" type="button">
# <div aria-hidden="false" class="Common-Booking-MultiBookProvider Theme-button-small expensive " id="c3acs">
# <a aria-label="$4072" class="booking-link" href="/book/flight?code=EqACLXCXSy.PRL1ZCExYWekNHvY8tYomQ.407101.3a7c97e289db6b4993193512e17fbfc3&amp;h=17c359e98239&amp;sub=E-1533ad4ed2e" id="c3acs-booking-link" role="button" tabindex="0" target="_blank">
# <span class="custom-text">
# $4072
# </span>
# </a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </section>
# </div>
# </section>
# <div id="qU2s"></div>
# </div>
# </div>
# </div>
# <div id="esMV"></div>
# </div>
# </div>
# </div>
# </div>
# <div id="FlightResultsDataLayer"></div>
# ;
