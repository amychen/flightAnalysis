# %%
import requests
from bs4 import BeautifulSoup
from lxml import html
import json
import pandas as pd
import re
import seaborn as sns
import datetime
from datetime import timedelta
import numpy as np

# %%
airport_code = ['LAS', 'LAX', 'CHI', 'SFO', 'ORL', 'DEN', 'DCA', 'SEA', 'BOS']

day_delta = datetime.timedelta(days=1)
start_date = datetime.date(2018, 12, 22)
end_date = start_date + 11*day_delta

url_list = []
for i in range((end_date - start_date).days):
    day = start_date + i*day_delta
    for airport in airport_code: 
        url = 'https://www.kayak.com/flights/NYC-' + str(airport) + '/' + str(day) + '?sort=bestflight_a&fs=stops=0'
        url_list.append(url)

# %%
def create_flight_price_text(flight_url):
    r = requests.get('https://www.kayak.com')
    layer1Cookies = r.cookies

    flight_search_xhr = 'https://www.kayak.com/s/horizon/flights/results/FlightSearchPoll'

    params1 = {
        'searchId':'',
        'poll':'true',
        'pollNumber':'0',
        'applyFilters':'true',
        'filterState':'',
        'useViewStateFilterState':'false',
        'pageNumber':'1',
        'append':'false',
        'pollingId':'593601',  #interesting. explore further
        'requestReason':'POLL',
        'isSecondPhase':'false',
        'textAndPageLocations':'bottom,right',
        'displayAdPageLocations':'none',
        'existingAds':'false',
        'activeLeg':'-1',
        'view':'list',
        'renderPlusMinusThreeFlex':'false',
        'renderAirlineStopsMatrix':'false',
        'renderFlexHeader':'true',
        'tab':'flights',
        'pageOrigin':'F..FD..M0',
        'src':'',
        'searchingAgain':'',
        'c2s':'',
        'po':'',
        'personality':'',
        'provider':'',
        'isMulticity':'false',
        'flex_category':'exact',
        'oneway':'false',
        'nearby_origin':'false',
        'nearby_destination':'false',
        'countrySearch':'false',
        'travelers':'1',
        'adults':'1',
        'seniors':'0',
        'youth':'0',
        'child':'0',
        'seatInfant':'0',
        'lapInfant':'0',
        'cabin':'e',
        'cabinDisplayType':'Economy',
        'vertical':'flights',
        'url':flight_url,
        'id':'',
        'navigateToResults':'false',
        'ajaxts':'',
        'scriptsMetadata':'',
        'stylesMetadata':'',
    }
    
    headers = {
        'Host': 'www.kayak.com',
        'User-Agent': 'Chrome/63 (Macintosh; Intel Mac OS X 10.11; rv:57.0) Gecko/20100101 Firefox/57.0',
        'Accept': '*/*',
        'Accept-Language': 'en-US,en;q=0.5',
        'Referer': flight_url,
        'Content-Type': 'application/x-www-form-urlencoded',
        'X-CSRF': 'kAqI1NgGh$DJnEUpiSDOWpdQXzlgAwG8EVOCd$gXO08-hpumC4oNpaOjz15GO_q9a5FdZPonpC2kF4CBYjEPh14',
        'X-RequestId': 'flights#frontdoor#Ag$s9g',
        'X-Requested-With': 'XMLHttpRequest',
        'Content-Length': '1094'
    }


    result = requests.post(flight_search_xhr, headers = headers, data = params1, cookies = layer1Cookies)
    text = result.json()
    text = BeautifulSoup(text['content'], 'html.parser')
    return text;

# %%
def getPricePrediction(flight_url):
    prediction_url = "https://www.kayak.com/s/horizon/flights/results/FlightPricePredictionAction"
    flight_search_html = requests.get(flight_url)

    s_id = re.compile(r'searchID=(\w+)')
    matches = s_id.finditer(str(create_flight_price_text(url)))
    searchId = ""
    for m in matches:
        searchId = m.group(1)

    token = re.compile(r"""\"formtoken\":\"(.+)\"\,""")
    matches = token.finditer(flight_search_html.text)
    formtoken = ""
    for m in matches:
        formtoken = m.group(1)

    params = {
        'searchId': searchId,
        'formtoken': formtoken
    }
    
    headers = {
        'Host': 'www.kayak.com',
        'User-Agent': 'Chrome/63 (Macintosh; Intel Mac OS X 10.11; rv:57.0) Gecko/20100101 Firefox/57.0',
        'Accept': '*/*',
        'Accept-Language': 'en-US,en;q=0.5',
        'Referer': flight_url,
        'Content-Type': 'application/x-www-form-urlencoded',
        'X-CSRF': 'kAqI1NgGh$DJnEUpiSDOWpdQXzlgAwG8EVOCd$gXO08-hpumC4oNpaOjz15GO_q9a5FdZPonpC2kF4CBYjEPh14',
        'X-RequestId': 'flights#frontdoor#Ag$s9g',
        'X-Requested-With': 'XMLHttpRequest',
        'Content-Length': '1094'
    }

    
    advice = requests.post(prediction_url, headers=headers, data=params)
    print(advice.json())

# %%
for url in url_list:
    getPricePrediction(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-92fb32dca87e> in <module>()
#       1 for url in url_list:
# ----> 2     getPricePrediction(url)
#
# <ipython-input-4-09fe81215a64> in getPricePrediction(flight_url)
#      21
#      22
# ---> 23     advice = requests.post(prediction_url, headers=headers, data=params)
#      24     print(advice.json())
#
# NameError: name 'headers' is not defined

# %%
def get_prices_times(text):
    doc = html.fromstring(str(text))
    flights = doc.xpath('//div[@class="Base-Results-HorizonResult Flights-Results-FlightResultItem phoenix-rising sleek rp-contrast "]')
    
    result = []
    for f in flights:
        price_info = f.get('aria-label')
        time_info = f.xpath('.//div//div//div//div[@class="col-info result-column"]')[0]
        time = time_info.xpath('.//div//div//ol//li//div//div//div//div//span//span[@class="depart-time base-time"]')[0].text
        am_pm = time_info.xpath('.//div//div//ol//li//div//div//div//div//span//span[@class="time-meridiem meridiem"]')[0].text
        
        regex_price = re.compile(r'(\$)(\d*)',re.VERBOSE)
        matches_price = regex_price.finditer(price_info)
        for match in matches_price:
            clean_price = match.group(2)
            entry = {
                'price' : clean_price,
                'time' : time + am_pm
            }
            result.append(entry)
        
    return result

# %%
def get_flights(html):
    flights = html.find_all('li', 'flight')
    result = []
    for f in flights:
        info = str(f.find('div', 'bottom'))
        info = info.replace('<div class="bottom">', '')
        info = info.replace("</div>", '')
        result.append(info)
        
    return result

# %%
for url in url_list:
    print(url)
    airline_dict = get_prices_times(create_flight_price_text(url))
    airline_list = get_flights(create_flight_price_text(url))
    for dic, airline in zip(airline_dict, airline_list):
        dic['airline'] = airline
    print(airline_dict)
    print('\n')
# Out:
# https://www.kayak.com/flights/NYC-LAS/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '313', 'time': '2:40 pm', 'airline': 'Spirit Airlines'}, {'price': '379', 'time': '7:55 pm', 'airline': 'American Airlines'}, {'price': '382', 'time': '9:16 pm', 'airline': 'JetBlue'}, {'price': '317', 'time': '10:15 am', 'airline': 'Spirit Airlines'}, {'price': '317', 'time': '7:20 am', 'airline': 'Spirit Airlines'}, {'price': '327', 'time': '2:40 pm', 'airline': 'Spirit Airlines'}, {'price': '382', 'time': '5:00 pm', 'airline': 'JetBlue'}, {'price': '389', 'time': '8:35 pm', 'airline': 'Delta'}, {'price': '398', 'time': '8:45 pm', 'airline': 'Spirit Airlines'}, {'price': '404', 'time': '5:18 pm', 'airline': 'JetBlue'}, {'price': '411', 'time': '8:35 am', 'airline': 'Spirit Airlines'}, {'price': '413', 'time': '5:59 pm', 'airline': 'Frontier'}, {'price': '431', 'time': '4:49 pm', 'airline': 'Spirit Airlines'}, {'price': '435', 'time': '8:45 pm', 'airline': 'Multiple Airlines'}, {'price': '437', 'time': '11:52 am', 'airline': 'Spirit Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-LAX/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '576', 'time': '11:52 am', 'airline': 'Spirit Airlines'}, {'price': '579', 'time': '6:00 pm', 'airline': 'Alaska Airlines'}, {'price': '599', 'time': '8:00 pm', 'airline': 'United Airlines'}, {'price': '582', 'time': '1:00 pm', 'airline': 'Spirit Airlines'}, {'price': '582', 'time': '9:00 am', 'airline': 'Alaska Airlines'}, {'price': '599', 'time': '7:02 pm', 'airline': 'Alaska Airlines'}, {'price': '663', 'time': '4:40 pm', 'airline': 'United Airlines'}, {'price': '663', 'time': '3:20 pm', 'airline': 'JetBlue'}, {'price': '697', 'time': '7:10 am', 'airline': 'JetBlue'}, {'price': '697', 'time': '8:20 pm', 'airline': 'Alaska Airlines'}, {'price': '697', 'time': '6:00 pm', 'airline': 'Alaska Airlines'}, {'price': '729', 'time': '4:00 pm', 'airline': 'United Airlines'}, {'price': '755', 'time': '8:59 am', 'airline': 'JetBlue'}, {'price': '785', 'time': '4:35 pm', 'airline': 'JetBlue'}, {'price': '799', 'time': '7:25 am', 'airline': 'JetBlue'}]
#
#
# https://www.kayak.com/flights/NYC-CHI/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '192', 'time': '9:59 pm', 'airline': 'Spirit Airlines'}, {'price': '297', 'time': '2:15 pm', 'airline': 'Delta'}, {'price': '319', 'time': '1:11 pm', 'airline': 'United Airlines'}, {'price': '268', 'time': '3:11 pm', 'airline': 'American Airlines'}, {'price': '270', 'time': '7:32 pm', 'airline': 'Delta'}, {'price': '286', 'time': '5:08 pm', 'airline': 'American Airlines'}, {'price': '287', 'time': '8:35 am', 'airline': 'Spirit Airlines'}, {'price': '294', 'time': '3:50 pm', 'airline': 'American Airlines'}, {'price': '294', 'time': '3:50 pm', 'airline': 'American Airlines'}, {'price': '294', 'time': '4:07 pm', 'airline': 'American Airlines'}, {'price': '294', 'time': '2:57 pm', 'airline': 'American Airlines'}, {'price': '297', 'time': '7:15 pm', 'airline': 'Delta'}, {'price': '319', 'time': '7:40 am', 'airline': 'United Airlines'}, {'price': '319', 'time': '6:37 pm', 'airline': 'United Airlines'}, {'price': '326', 'time': '4:30 pm', 'airline': 'Delta'}]
#
#
# https://www.kayak.com/flights/NYC-SFO/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '427', 'time': '8:30 pm', 'airline': 'JetBlue'}, {'price': '471', 'time': '7:15 pm', 'airline': 'Alaska Airlines'}, {'price': '482', 'time': '9:05 pm', 'airline': 'American Airlines'}, {'price': '467', 'time': '7:25 pm', 'airline': 'Delta'}, {'price': '471', 'time': '5:29 pm', 'airline': 'Alaska Airlines'}, {'price': '498', 'time': '7:30 am', 'airline': 'Alaska Airlines'}, {'price': '518', 'time': '8:30 pm', 'airline': 'United Airlines'}, {'price': '518', 'time': '7:35 pm', 'airline': 'United Airlines'}, {'price': '523', 'time': '9:30 pm', 'airline': 'Multiple Airlines'}, {'price': '523', 'time': '7:30 pm', 'airline': 'Multiple Airlines'}, {'price': '541', 'time': '4:59 pm', 'airline': 'Delta'}, {'price': '541', 'time': '1:55 pm', 'airline': 'Delta'}, {'price': '547', 'time': '9:30 pm', 'airline': 'Multiple Airlines'}, {'price': '548', 'time': '9:59 pm', 'airline': 'United Airlines'}, {'price': '557', 'time': '5:18 pm', 'airline': 'JetBlue'}]
#
#
# https://www.kayak.com/flights/NYC-ORL/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '232', 'time': '10:15 am', 'airline': 'Spirit Airlines'}, {'price': '382', 'time': '8:45 pm', 'airline': 'United Airlines'}, {'price': '425', 'time': '9:02 pm', 'airline': 'JetBlue'}, {'price': '232', 'time': '8:45 pm', 'airline': 'Spirit Airlines'}, {'price': '232', 'time': '7:20 am', 'airline': 'Spirit Airlines'}, {'price': '277', 'time': '2:40 pm', 'airline': 'Spirit Airlines'}, {'price': '282', 'time': '11:10 am', 'airline': 'Spirit Airlines'}, {'price': '282', 'time': '4:49 pm', 'airline': 'Spirit Airlines'}, {'price': '337', 'time': '1:15 pm', 'airline': 'Spirit Airlines'}, {'price': '382', 'time': '8:35 am', 'airline': 'Spirit Airlines'}, {'price': '382', 'time': '2:40 pm', 'airline': 'Multiple Airlines'}, {'price': '382', 'time': '9:45 am', 'airline': 'Spirit Airlines'}, {'price': '392', 'time': '1:54 pm', 'airline': 'Spirit Airlines'}, {'price': '407', 'time': '7:59 pm', 'airline': 'Delta'}, {'price': '425', 'time': '6:00 am', 'airline': 'JetBlue'}]
#
#
# https://www.kayak.com/flights/NYC-DEN/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '332', 'time': '9:59 pm', 'airline': 'Spirit Airlines'}, {'price': '352', 'time': '9:03 pm', 'airline': 'American Airlines'}, {'price': '363', 'time': '8:00 pm', 'airline': 'American Airlines'}, {'price': '343', 'time': '10:15 am', 'airline': 'American Airlines'}, {'price': '389', 'time': '8:45 pm', 'airline': 'American Airlines'}, {'price': '406', 'time': '5:00 pm', 'airline': 'Southwest'}, {'price': '409', 'time': '9:59 pm', 'airline': 'Southwest'}, {'price': '412', 'time': '1:55 pm', 'airline': 'Southwest'}, {'price': '412', 'time': '1:55 pm', 'airline': 'Southwest'}, {'price': '429', 'time': '2:40 pm', 'airline': 'Southwest'}, {'price': '451', 'time': '6:19 pm', 'airline': 'JetBlue'}, {'price': '464', 'time': '9:30 pm', 'airline': 'United Airlines'}, {'price': '469', 'time': '6:24 pm', 'airline': 'Delta'}, {'price': '480', 'time': '9:45 am', 'airline': 'American Airlines'}, {'price': '481', 'time': '6:20 pm', 'airline': 'JetBlue'}]
#
#
# https://www.kayak.com/flights/NYC-DCA/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '116', 'time': '8:30 pm', 'airline': 'Delta'}, {'price': '171', 'time': '8:44 pm', 'airline': 'United Airlines'}, {'price': '171', 'time': '10:51 am', 'airline': 'American Airlines'}, {'price': '166', 'time': '8:40 am', 'airline': 'Delta'}, {'price': '171', 'time': '6:25 pm', 'airline': 'United Airlines'}, {'price': '171', 'time': '5:15 pm', 'airline': 'American Airlines'}, {'price': '171', 'time': '3:43 pm', 'airline': 'American Airlines'}, {'price': '211', 'time': '2:50 pm', 'airline': 'Delta'}, {'price': '246', 'time': '12:31 pm', 'airline': 'United Airlines'}, {'price': '246', 'time': '9:00 am', 'airline': 'United Airlines'}, {'price': '246', 'time': '2:03 pm', 'airline': 'United Airlines'}, {'price': '251', 'time': '7:00 pm', 'airline': 'Delta'}, {'price': '251', 'time': '3:00 pm', 'airline': 'Delta'}, {'price': '251', 'time': '10:00 am', 'airline': 'Delta'}, {'price': '269', 'time': '9:40 am', 'airline': 'American Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-SEA/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '380', 'time': '2:40 pm', 'airline': 'Spirit Airlines'}, {'price': '486', 'time': '6:37 pm', 'airline': 'Delta'}, {'price': '499', 'time': '6:40 pm', 'airline': 'Alaska Airlines'}, {'price': '385', 'time': '9:45 am', 'airline': 'Spirit Airlines'}, {'price': '500', 'time': '8:35 am', 'airline': 'Spirit Airlines'}, {'price': '518', 'time': '7:30 am', 'airline': 'Alaska Airlines'}, {'price': '549', 'time': '6:35 pm', 'airline': 'American Airlines'}, {'price': '552', 'time': '5:59 am', 'airline': 'American Airlines'}, {'price': '557', 'time': '5:08 pm', 'airline': 'American Airlines'}, {'price': '580', 'time': '3:45 pm', 'airline': 'Delta'}, {'price': '580', 'time': '7:00 am', 'airline': 'Delta'}, {'price': '596', 'time': '7:20 am', 'airline': 'Spirit Airlines'}, {'price': '597', 'time': '1:54 pm', 'airline': 'Spirit Airlines'}, {'price': '599', 'time': '4:10 pm', 'airline': 'Alaska Airlines'}, {'price': '599', 'time': '6:00 am', 'airline': 'Alaska Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-BOS/2018-12-22?sort=bestflight_a&fs=stops=0
# [{'price': '96', 'time': '8:30 pm', 'airline': 'United Airlines'}, {'price': '111', 'time': '10:55 pm', 'airline': 'JetBlue'}, {'price': '113', 'time': '9:30 pm', 'airline': 'American Airlines'}, {'price': '96', 'time': '7:35 pm', 'airline': 'United Airlines'}, {'price': '111', 'time': '5:29 pm', 'airline': 'United Airlines'}, {'price': '123', 'time': '6:41 am', 'airline': 'Delta'}, {'price': '141', 'time': '1:30 pm', 'airline': 'United Airlines'}, {'price': '141', 'time': '6:00 am', 'airline': 'JetBlue'}, {'price': '141', 'time': '8:00 pm', 'airline': 'JetBlue'}, {'price': '143', 'time': '12:55 pm', 'airline': 'American Airlines'}, {'price': '143', 'time': '9:40 am', 'airline': 'American Airlines'}, {'price': '143', 'time': '7:55 am', 'airline': 'American Airlines'}, {'price': '147', 'time': '5:18 pm', 'airline': 'JetBlue'}, {'price': '164', 'time': '9:30 am', 'airline': 'JetBlue'}, {'price': '174', 'time': '10:00 am', 'airline': 'American Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-LAS/2018-12-23?sort=bestflight_a&fs=stops=0
# [{'price': '248', 'time': '8:15 am', 'airline': 'Spirit Airlines'}, {'price': '307', 'time': '9:00 pm', 'airline': 'JetBlue'}, {'price': '365', 'time': '9:39 pm', 'airline': 'United Airlines'}, {'price': '262', 'time': '9:59 pm', 'airline': 'Spirit Airlines'}, {'price': '293', 'time': '1:33 pm', 'airline': 'Spirit Airlines'}, {'price': '301', 'time': '8:35 pm', 'airline': 'Delta'}, {'price': '334', 'time': '1:33 pm', 'airline': 'Spirit Airlines'}, {'price': '341', 'time': '7:30 pm', 'airline': 'JetBlue'}, {'price': '349', 'time': '5:15 pm', 'airline': 'Delta'}, {'price': '357', 'time': '10:15 am', 'airline': 'Spirit Airlines'}, {'price': '363', 'time': '8:35 am', 'airline': 'Spirit Airlines'}, {'price': '366', 'time': '4:49 pm', 'airline': 'Spirit Airlines'}, {'price': '371', 'time': '8:35 am', 'airline': 'Spirit Airlines'}, {'price': '376', 'time': '7:20 am', 'airline': 'Spirit Airlines'}, {'price': '382', 'time': '5:35 pm', 'airline': 'JetBlue'}]
#
#
# https://www.kayak.com/flights/NYC-LAX/2018-12-23?sort=bestflight_a&fs=stops=0
# []
#
#
# https://www.kayak.com/flights/NYC-CHI/2018-12-23?sort=bestflight_a&fs=stops=0
# [{'price': '131', 'time': '9:59 pm', 'airline': 'Spirit Airlines'}, {'price': '209', 'time': '9:29 pm', 'airline': 'American Airlines'}, {'price': '328', 'time': '7:00 am', 'airline': 'Spirit Airlines'}, {'price': '562', 'time': '8:20 pm', 'airline': 'American Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-SFO/2018-12-23?sort=bestflight_a&fs=stops=0
# [{'price': '314', 'time': '5:29 pm', 'airline': 'Alaska Airlines'}, {'price': '322', 'time': '8:30 pm', 'airline': 'JetBlue'}, {'price': '349', 'time': '10:00 pm', 'airline': 'United Airlines'}, {'price': '316', 'time': '10:50 pm', 'airline': 'Frontier'}, {'price': '317', 'time': '8:15 am', 'airline': 'Multiple Airlines'}, {'price': '317', 'time': '8:15 am', 'airline': 'Multiple Airlines'}, {'price': '317', 'time': '8:15 am', 'airline': 'Multiple Airlines'}, {'price': '322', 'time': '7:00 pm', 'airline': 'United Airlines'}, {'price': '322', 'time': '7:00 pm', 'airline': 'United Airlines'}, {'price': '322', 'time': '2:36 pm', 'airline': 'United Airlines'}, {'price': '325', 'time': '8:15 am', 'airline': 'Multiple Airlines'}, {'price': '349', 'time': '9:00 pm', 'airline': 'United Airlines'}, {'price': '357', 'time': '6:44 pm', 'airline': 'United Airlines'}, {'price': '357', 'time': '6:37 pm', 'airline': 'United Airlines'}, {'price': '357', 'time': '6:37 pm', 'airline': 'United Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-ORL/2018-12-23?sort=bestflight_a&fs=stops=0
# [{'price': '222', 'time': '4:49 pm', 'airline': 'Spirit Airlines'}, {'price': '308', 'time': '9:02 pm', 'airline': 'JetBlue'}, {'price': '333', 'time': '6:59 pm', 'airline': 'United Airlines'}, {'price': '222', 'time': '9:45 am', 'airline': 'Spirit Airlines'}, {'price': '229', 'time': '9:29 am', 'airline': 'Frontier'}, {'price': '238', 'time': '9:45 am', 'airline': 'Spirit Airlines'}, {'price': '241', 'time': '8:35 am', 'airline': 'Spirit Airlines'}, {'price': '256', 'time': '1:33 pm', 'airline': 'Spirit Airlines'}, {'price': '262', 'time': '10:15 am', 'airline': 'Spirit Airlines'}, {'price': '262', 'time': '8:45 pm', 'airline': 'Spirit Airlines'}, {'price': '262', 'time': '3:30 pm', 'airline': 'Spirit Airlines'}, {'price': '308', 'time': '6:00 am', 'airline': 'JetBlue'}, {'price': '308', 'time': '12:10 pm', 'airline': 'JetBlue'}, {'price': '308', 'time': '1:54 pm', 'airline': 'JetBlue'}, {'price': '324', 'time': '1:33 pm', 'airline': 'Spirit Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-DEN/2018-12-23?sort=bestflight_a&fs=stops=0
# [{'price': '210', 'time': '1:54 pm', 'airline': 'Spirit Airlines'}, {'price': '262', 'time': '8:00 pm', 'airline': 'JetBlue'}, {'price': '280', 'time': '8:18 pm', 'airline': 'United Airlines'}, {'price': '232', 'time': '9:45 am', 'airline': 'Spirit Airlines'}, {'price': '251', 'time': '8:35 am', 'airline': 'Spirit Airlines'}, {'price': '258', 'time': '9:03 pm', 'airline': 'Delta'}, {'price': '280', 'time': '6:44 pm', 'airline': 'United Airlines'}, {'price': '292', 'time': '3:30 pm', 'airline': 'Spirit Airlines'}, {'price': '302', 'time': '9:59 pm', 'airline': 'Spirit Airlines'}, {'price': '311', 'time': '12:30 pm', 'airline': 'Spirit Airlines'}, {'price': '312', 'time': '6:15 pm', 'airline': 'Delta'}, {'price': '318', 'time': '8:15 am', 'airline': 'Spirit Airlines'}, {'price': '359', 'time': '3:58 pm', 'airline': 'JetBlue'}, {'price': '370', 'time': '3:52 pm', 'airline': 'United Airlines'}, {'price': '370', 'time': '4:59 pm', 'airline': 'United Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-DCA/2018-12-23?sort=bestflight_a&fs=stops=0
# [{'price': '126', 'time': '8:30 pm', 'airline': 'American Airlines'}, {'price': '171', 'time': '11:26 am', 'airline': 'Delta'}]
#
#
# https://www.kayak.com/flights/NYC-SEA/2018-12-23?sort=bestflight_a&fs=stops=0
# [{'price': '295', 'time': '9:45 am', 'airline': 'Spirit Airlines'}, {'price': '315', 'time': '6:35 pm', 'airline': 'American Airlines'}, {'price': '333', 'time': '6:30 pm', 'airline': 'United Airlines'}, {'price': '309', 'time': '9:59 pm', 'airline': 'Spirit Airlines'}, {'price': '310', 'time': '8:15 am', 'airline': 'Spirit Airlines'}, {'price': '348', 'time': '8:15 am', 'airline': 'Spirit Airlines'}, {'price': '348', 'time': '8:15 am', 'airline': 'Spirit Airlines'}, {'price': '349', 'time': '6:40 pm', 'airline': 'Alaska Airlines'}, {'price': '349', 'time': '6:00 am', 'airline': 'Alaska Airlines'}, {'price': '357', 'time': '3:45 pm', 'airline': 'Delta'}, {'price': '357', 'time': '6:37 pm', 'airline': 'Delta'}, {'price': '363', 'time': '5:44 pm', 'airline': 'JetBlue'}, {'price': '383', 'time': '5:30 pm', 'airline': 'Delta'}, {'price': '394', 'time': '4:41 pm', 'airline': 'United Airlines'}, {'price': '399', 'time': '4:10 pm', 'airline': 'Alaska Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-BOS/2018-12-23?sort=bestflight_a&fs=stops=0
# [{'price': '83', 'time': '9:30 pm', 'airline': 'JetBlue'}, {'price': '98', 'time': '8:00 pm', 'airline': 'American Airlines'}, {'price': '143', 'time': '8:00 pm', 'airline': 'United Airlines'}, {'price': '478', 'time': '12:00 pm', 'airline': 'JetBlue'}]
#
#
# https://www.kayak.com/flights/NYC-LAS/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '240', 'time': '8:15 am', 'airline': 'Spirit Airlines'}, {'price': '281', 'time': '7:30 pm', 'airline': 'American Airlines'}, {'price': '296', 'time': '7:55 pm', 'airline': 'American Airlines'}, {'price': '313', 'time': '9:00 pm', 'airline': 'JetBlue'}, {'price': '326', 'time': '7:30 am', 'airline': 'American Airlines'}, {'price': '350', 'time': '8:07 am', 'airline': 'American Airlines'}, {'price': '378', 'time': '7:00 am', 'airline': 'American Airlines'}, {'price': '382', 'time': '1:55 pm', 'airline': 'Hawaiian Airlines'}, {'price': '386', 'time': '5:08 pm', 'airline': 'JetBlue'}, {'price': '400', 'time': '8:57 am', 'airline': 'JetBlue'}, {'price': '404', 'time': '5:18 pm', 'airline': 'JetBlue'}, {'price': '464', 'time': '11:31 am', 'airline': 'Southwest'}, {'price': '1282', 'time': '12:16 pm', 'airline': 'United Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-LAX/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '334', 'time': '12:16 pm', 'airline': 'Spirit Airlines'}, {'price': '338', 'time': '6:00 pm', 'airline': 'American Airlines'}, {'price': '429', 'time': '5:00 pm', 'airline': 'Sun Country Air'}, {'price': '334', 'time': '11:06 am', 'airline': 'American Airlines'}, {'price': '334', 'time': '10:40 pm', 'airline': 'American Airlines'}, {'price': '334', 'time': '9:40 pm', 'airline': 'American Airlines'}, {'price': '334', 'time': '4:40 pm', 'airline': 'American Airlines'}, {'price': '334', 'time': '7:41 pm', 'airline': 'American Airlines'}, {'price': '338', 'time': '5:30 pm', 'airline': 'American Airlines'}, {'price': '338', 'time': '4:00 pm', 'airline': 'American Airlines'}, {'price': '338', 'time': '9:00 am', 'airline': 'Delta'}, {'price': '344', 'time': '3:20 pm', 'airline': 'Southwest'}, {'price': '365', 'time': '4:49 pm', 'airline': 'Southwest'}, {'price': '392', 'time': '2:00 pm', 'airline': 'American Airlines'}, {'price': '392', 'time': '12:00 pm', 'airline': 'JetBlue'}, {'price': '392', 'time': '10:07 am'}]
#
#
# https://www.kayak.com/flights/NYC-CHI/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '121', 'time': '9:59 pm', 'airline': 'Spirit Airlines'}, {'price': '234', 'time': '4:01 pm', 'airline': 'United Airlines'}, {'price': '172', 'time': '5:46 am', 'airline': 'American Airlines'}, {'price': '212', 'time': '1:55 pm', 'airline': 'American Airlines'}, {'price': '221', 'time': '6:30 am', 'airline': 'American Airlines'}, {'price': '238', 'time': '8:45 pm', 'airline': 'United Airlines'}, {'price': '241', 'time': '5:00 am', 'airline': 'Southwest'}]
#
#
# https://www.kayak.com/flights/NYC-SFO/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '314', 'time': '7:15 am', 'airline': 'Alaska Airlines'}, {'price': '372', 'time': '4:10 pm', 'airline': 'JetBlue'}, {'price': '314', 'time': '10:15 am', 'airline': 'United Airlines'}, {'price': '314', 'time': '7:15 pm', 'airline': 'Alaska Airlines'}, {'price': '314', 'time': '5:29 pm', 'airline': 'JetBlue'}, {'price': '322', 'time': '4:55 pm', 'airline': 'Alaska Airlines'}, {'price': '322', 'time': '7:00 am', 'airline': 'United Airlines'}, {'price': '322', 'time': '9:30 am', 'airline': 'United Airlines'}, {'price': '322', 'time': '11:30 am', 'airline': 'United Airlines'}, {'price': '372', 'time': '6:30 pm', 'airline': 'Alaska Airlines'}, {'price': '532', 'time': '5:00 pm', 'airline': 'Alaska Airlines'}, {'price': '551', 'time': '11:00 am', 'airline': 'Delta'}]
#
#
# https://www.kayak.com/flights/NYC-ORL/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '167', 'time': '10:15 am', 'airline': 'Spirit Airlines'}, {'price': '197', 'time': '9:18 am', 'airline': 'Allegiant Air'}, {'price': '340', 'time': '6:30 am', 'airline': 'American Airlines'}, {'price': '379', 'time': '10:14 am', 'airline': 'American Airlines'}, {'price': '591', 'time': '6:50 pm', 'airline': 'JetBlue'}, {'price': '897', 'time': '10:35 am', 'airline': 'Southwest'}]
#
#
# https://www.kayak.com/flights/NYC-DEN/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '151', 'time': '8:00 pm', 'airline': 'Spirit Airlines'}, {'price': '225', 'time': '6:44 pm', 'airline': 'Delta'}, {'price': '229', 'time': '2:50 pm', 'airline': 'Delta'}, {'price': '207', 'time': '8:35 am', 'airline': 'JetBlue'}, {'price': '225', 'time': '9:10 am', 'airline': 'American Airlines'}, {'price': '258', 'time': '4:55 pm', 'airline': 'American Airlines'}, {'price': '262', 'time': '2:21 pm', 'airline': 'American Airlines'}, {'price': '262', 'time': '12:00 pm', 'airline': 'JetBlue'}, {'price': '264', 'time': '1:55 pm', 'airline': 'American Airlines'}, {'price': '280', 'time': '3:52 pm', 'airline': 'Southwest'}, {'price': '280', 'time': '6:25 am', 'airline': 'Southwest'}, {'price': '280', 'time': '11:59 am', 'airline': 'Southwest'}, {'price': '324', 'time': '8:57 am', 'airline': 'Southwest'}, {'price': '339', 'time': '6:30 am', 'airline': 'JetBlue'}, {'price': '347', 'time': '7:00 am', 'airline': 'Southwest'}]
#
#
# https://www.kayak.com/flights/NYC-DCA/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '169', 'time': '12:30 pm', 'airline': 'Delta'}, {'price': '185', 'time': '5:10 am', 'airline': 'United Airlines'}, {'price': '200', 'time': '6:31 am', 'airline': 'JetBlue'}, {'price': '356', 'time': '4:00 pm', 'airline': 'JetBlue'}, {'price': '569', 'time': '7:25 am', 'airline': 'American Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-SEA/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '263', 'time': '6:35 pm', 'airline': 'American Airlines'}, {'price': '292', 'time': '6:15 pm', 'airline': 'Alaska Airlines'}, {'price': '446', 'time': '11:05 am', 'airline': 'Alaska Airlines'}, {'price': '486', 'time': '1:55 pm', 'airline': 'Alaska Airlines'}, {'price': '502', 'time': '5:59 am', 'airline': 'Alaska Airlines'}, {'price': '843', 'time': '5:00 am', 'airline': 'Alaska Airlines'}]
#
#
# https://www.kayak.com/flights/NYC-BOS/2018-12-24?sort=bestflight_a&fs=stops=0
# [{'price': '83', 'time': '9:30 pm', 'airline': 'American Airlines'}, {'price': '96', 'time': '6:30 am', 'airline': 'JetBlue'}, {'price': '143', 'time': '10:00 am', 'airline': 'American Airlines'}, {'price': '164', 'time': '1:15 pm', 'airline': 'Delta'}]
#
#
# https://www.kayak.com/flights/NYC-LAS/2018-12-25?sort=bestflight_a&fs=stops=0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0014494fe758> in <module>()
#       1 for url in url_list:
#       2     print(url)
# ----> 3     airline_dict = get_prices_times(create_flight_price_text(url))
#       4     airline_list = get_flights(create_flight_price_text(url))
#       5     for dic, airline in zip(airline_dict, airline_list):
#
# <ipython-input-3-d6947d7df767> in create_flight_price_text(flight_url)
#      73     result = requests.post(flight_search_xhr, headers = headers, data = params1, cookies = layer1Cookies)
#      74     text = result.json()
# ---> 75     text = BeautifulSoup(text['content'], 'html.parser')
#      76     return text;
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     213         parser.soup = self.soup
#     214         try:
# --> 215             parser.feed(markup)
#     216         except HTMLParseError as e:
#     217             warnings.warn(RuntimeWarning(
#
# ~/anaconda3/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~/anaconda3/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~/anaconda3/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     312         assert match, 'unexpected call to parse_starttag()'
#     313         k = match.end()
# --> 314         self.lasttag = tag = match.group(1).lower()
#     315         while k < endpos:
#     316             m = attrfind_tolerant.match(rawdata, k)
#
# KeyboardInterrupt:
