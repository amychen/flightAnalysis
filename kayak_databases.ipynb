# %%
import requests
from sqlalchemy import create_engine
from datetime import datetime

# %%
conn_string = 'mysql://{user}:{password}@{host}/'.format(
                host = '35.237.252.223',
                user = 'root',
                password = 'x3rGjkz93e6CIkd7')
engine = create_engine(conn_string)
con = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-6840faf86923> in <module>()
#       3                 user = 'root',
#       4                 password = 'x3rGjkz93e6CIkd7')
# ----> 5 engine = create_engine(conn_string)
#       6 con = engine.connect()
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     385     strategy = kwargs.pop('strategy', default_strategy)
#     386     strategy = strategies.strategies[strategy]
# --> 387     return strategy.create(*args, **kwargs)
#     388
#     389
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      78                 if k in kwargs:
#      79                     dbapi_args[k] = pop_kwarg(k)
# ---> 80             dbapi = dialect_cls.dbapi(**dbapi_args)
#      81
#      82         dialect_args['dbapi'] = dbapi
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in dbapi(cls)
#     108     @classmethod
#     109     def dbapi(cls):
# --> 110         return __import__('MySQLdb')
#     111
#     112     def do_executemany(self, cursor, statement, parameters, context=None):
#
# ModuleNotFoundError: No module named 'MySQLdb'

# %%
engine.execute("CREATE DATABASE IF NOT EXISTS kayak")

# %%
sql = '''
CREATE TABLE IF NOT EXISTS kayak.flight (
    airline varchar(50), 
    
)
'''
